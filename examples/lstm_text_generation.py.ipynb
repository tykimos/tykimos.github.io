# %% [markdown]
# 이번 예제는 니체의 글을 훈련시켜 글을 생성하는 것입니다. 적절한 수준이 되려면 적어도 20번의 반복훈 훈련이 필요합니다. Recurrent network는 계산량이 꽤 많기 때문에 이 예제는 GPU에서 동작시키길을 권장합니다. 이 예제를 새로운 데이터에 적용시키고자 한다면, 적어도 십만이상의 문자가 필요하고 백만이면 더 좋습니다.

# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''
# Out:
# "Example script to generate text from Nietzsche's writings.\n\nAt least 20 epochs are required before the generated text\nstarts sounding coherent.\n\nIt is recommended to run this script on GPU, as recurrent\nnetworks are quite computationally intensive.\n\nIf you try this script on new data, make sure your corpus\nhas at least ~100k characters. ~1M is better.\n"

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
# Out:
# Using Theano backend.

# %% [markdown]
# <img src='./img01.jpg'>

# %%
path = get_file('nietzsche.txt', origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600901
# total chars: 59

# %%
print (path)
# Out:
# /Users/tykimos/.keras/datasets/nietzsche.txt

# %% [markdown]
# 다운받은 nietzsche.txt의 경로는 "print (path)"으로 알아봅니다. nietzsche.txt 샘플은 다음과 같습니다.
#
# <img src="img01.png">

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 200287
# Vectorization...

# %%
# build the model: 2 stacked LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(512, return_sequences=True, input_shape=(maxlen, len(chars))))
model.add(LSTM(512, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
# Out:
# Build model...

# %%
def sample(a, temperature=1.0):
    # helper function to sample an index from a probability array
    a = np.log(a) / temperature
    a = np.exp(a) / np.sum(np.exp(a))
    return np.argmax(np.random.multinomial(1, a, 1))

# %%
# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=128, nb_epoch=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200287/200287 [==============================] - 2858s - loss: 2.7943
#
# ----- diversity: 0.2
# ----- Generating with seed: " things. on the contrary he thought he e"
#  things. on the contrary he thought he ererent in the the the the the the the the the the the the the the the the the the the the the ho the the the the the the the the the the the the the the the the the the the the the the the in the the the the the the the the the the the the the the the he the the the the the the the the the the the the the mere the the and the the the the the the the the the the the the the the the the the wher the
#
# ----- diversity: 0.5
# ----- Generating with seed: " things. on the contrary he thought he e"
#  things. on the contrary he thought he erer on ind the core ot rererith he he rethen as anus the rathe salithan in on me the the in the the al the the the in ho whe the the dane al in de lend tho mimlew th al or the the fethe and, whe soth pererer or ase pate sot man the the the the the the the gere the ther pante ho the seres and on the peresith of af mag ol he the inse we the and of ol whe the the the the mere the the serer in the ere
#
# ----- diversity: 1.0
# ----- Generating with seed: " things. on the contrary he thought he e"
#  things. on the contrary he thought he erecini, in ofd, chmlinstus is mcinn the pcicultuma chet mon tho wonth
# ac in hissuns ced oubemlnighe tan [or vho
# ufe? is foth keverner hur iis hithe the in , ootisot cnak aley piny natyze, lf 7rene tolel ano lre
# boses'r, the it toss pouthe tustevurt
# ant amuer, lit mrinwurpertian
# ly of it olelenm. wo
# tho burtludeslar;ats olleidath jo andid misgilitis bo thet rer theraise uct
# vrsuth selront ard encit
#
# ----- diversity: 1.2
# ----- Generating with seed: " things. on the contrary he thought he e"
#  things. on the contrary he thought he en uproejit
# io the tho
# imis!"t, it antr in)
# fony one mus fhe puevasiryida overiblit wy thet.e d thethe
# s an ir"ec_egmaslif-ond hilimjg-iftils, mhet rothetac--av thal pilecasyt3y th virsik the corgto-t adiphenar 9roches
# ricwethe br ursrutite then in nho
# tereoas�y, "lemsry is asnege do
# s es fe cettinn,
# a,y sithe non=-to
# 'olith, gmumhaqn of asd evith umed auldp she'tek ecte plarhribos chro hals; rboy
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200287/200287 [==============================] - 2631s - loss: 2.3005
#
# ----- diversity: 0.2
# ----- Generating with seed: "cratic society and so it will always be-"
# cratic society and so it will always be-and and in the the inserite the sores the sore the and ithere the somest of the insaling in the sering the coment and asterting in the soment and in the soment in the of in the resterting and in the fore wore the moment and in the somert and in the soment and the insingert and in the conestion the roust and the soment in the songers and the mant the compint in the somest the there the sore the som
#
# ----- diversity: 0.5
# ----- Generating with seed: "cratic society and so it will always be-"
# cratic society and so it will always be-than the reomething the purese the epriatensire inserther thel heremanting and soperate ther themestenings and mist of indeangisesiting in manty on the imaninital on
# morations hace the espiand the erens thenerteres mening of master, the herertosand the conserisall of the ralioned the cisitions atle the mante of shecancinger, the hiss itserally and ot en in atroule inos mofrect, in
# a the mrosaliby
#
# ----- diversity: 1.0
# ----- Generating with seed: "cratic society and so it will always be-"
# cratic society and so it will always be-moung,-,"thime", leaced, tho gheite selpistane teelyuzcies of floreg, huch ant the porein? asde tithungcengrye-ndore, horhing is itrealls nand
# ertor: engare ent reubciles wo h
# thich to the rrot_uns it and thige and tout evar inleartion
# -fho kese cirsibion they treditsingd" the issijns and atwerr as is
# andaale
#
# the
# gars" und whall too- biwher
# toumlr it ies, hho pereof rampsong, [
# re rotetertiple. i
#
# ----- diversity: 1.2
# ----- Generating with seed: "cratic society and so it will always be-"
# cratic society and so it will always be-wher who minesion) aracesmertaliul themeng an eubtiver, )recotoen sonurg
# mei. ofever. thy theok whe
# ringlcancties,- ththe?h ves4 gurcens
# andieniont) _atiins,
# se"s, sumal to agh fon simoig =or gho winde
# -deruissl
# bxeveswel;
# sias acf-btad chajcomnes exdeosuree womndand
# arorung:y in tset apem, tha beogare theurssstoon. boagf
# ntserendite, as sragle-nnuthin whoos to e itherf richifacnlyv in jughait erd
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200287/200287 [==============================] - 2580s - loss: 2.0865
#
# ----- diversity: 0.2
# ----- Generating with seed: "o doubt that a certain virtus dormitiva "
# o doubt that a certain virtus dormitiva in the sulloge and the sould the prosicions and and the sould the sould the sould the sould of the sould the sould the sould and the his all the sould the sould and the sould the sould the sould of the presting to the sould the sere the self and the sould the sould the self the sould the sould the sould to the sould and the sould the self the sould the sould to the sould that it it is it ore and s
#
# ----- diversity: 0.5
# ----- Generating with seed: "o doubt that a certain virtus dormitiva "
# o doubt that a certain virtus dormitiva it ullogy and the soul in the sould and it is the sure which a deviling to the sould of the gore in the arour ray lough as the that it is not will the incilition of the dighind worl wall, a dould of the pare of in the indighing mane and somentions and beligy that is it is a very the sould brouth in the tore as instorions and silf actand of phall gors of the
# carer that in the exered of disenter of
#
# ----- diversity: 1.0
# ----- Generating with seed: "o doubt that a certain virtus dormitiva "
# o doubt that a certain virtus dormitiva atheunce momulufs--trile, gore in
# as exciele of caruling as coulf, to weirg, wative, fires, hand itsors of
# mallire sendeds. by tho edbited furd him le rlind reingtang 8ave and axtore lisies sial 9ame
# thay and the suce in propledcs, dalok of
# exver-fo wirlosofiztens, as by greans, ho anl lay beow it is
# willy-wand a by etring,--[wes lideriogs, asnicet": is
# oure sommerianle cuilly the alite all unot c
#
# ----- diversity: 1.2
# ----- Generating with seed: "o doubt that a certain virtus dormitiva "
# o doubt that a certain virtus dormitiva sor9 mocm,
# �ars forkig, be upotos) mast guras aing prouid
# repte-sing bshoucs, what ore is love and hadpe prigitaid,
# "now,! ipxacoplond" ex gerkenimy;.
# "1irste suste cam. ias. it nat ivrultor amevs dits, ald shal
# ighorpsty is!ood.---it hiposh itswerf:--cowed a far ad the calply: a hof ham
# partaediwy,- thy concaicion, bat, to prowas, and
# the rerfoce; it to a bireent hinfan that painiouts nisld-,act,
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200287/200287 [==============================] - 2595s - loss: 1.9335
#
# ----- diversity: 0.2
# ----- Generating with seed: "bove all, it is not obvious to them whet"
# bove all, it is not obvious to them whet the stronge of the some and the self-certain of the something the sould the some the somether of the who the who has who has a phiconoun the sould the for and and the one the stronging the prestion of the some and the which consiction of the some in his of the songeration of the conserfation of the strongion of the conserition of the something the sould of the concemting and in the soult of the r
#
# ----- diversity: 0.5
# ----- Generating with seed: "bove all, it is not obvious to them whet"
# bove all, it is not obvious to them whet which
# which the somethesty be one chass of the mist and which a conction
# it not in the spilition of which at it more and and must mergon the
# will not in ow evor the wend the exolition of the concemantion
# of the sentiming for the masticion in the ore for shimens to nature of the whill has conture, the supher the presting of a raghars of the strong the
# conception of the rights and in this our and o
#
# ----- diversity: 1.0
# ----- Generating with seed: "bove all, it is not obvious to them whet"
# bove all, it is not obvious to them whet foll be
# precoest and oun nitucolinationis geoors, wharating, the
# levherephosk be hthings thay shep is evoly inetinces s1porafle
# to und serflecciousting with wat econaquation for the
# somoteg!tas od appeinecs, tfo to roised in instand ovatate of
# agintio2, at, as preperspty, and the kider
# oe _hinht in tha word of intappe, in the
# monalness ow ythe berightanderllegs to be a wheman itself=l. bo
# the fou
#
# ----- diversity: 1.2
# ----- Generating with seed: "bove all, it is not obvious to them whet"
# bove all, it is not obvious to them wheter how thor
# froberhitirale, the podentey it is a mos, evarsiviste.
# the somhint of grately: in who mean it srounds fringarty a pines of in
# andiccavevy bricts ntilkly selvacing chesppeaally even whocon but
# looks. this not indiontion, of
# thiskein the oumenerit at thungalstian4ly affwionlyyly
# 1a tands fon, winl? the botnesstion a�iam us a thineatece, and
# "ac, wish whinks]-gand:? flanwsedenge pcandyow
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200287/200287 [==============================] - 2601s - loss: 1.8099
#
# ----- diversity: 0.2
# ----- Generating with seed: "he conception of the world which has bee"
# he conception of the world which has been and the manking of the most of the proponity of the posion of the most of the possion of the possice of the proposition of the something of the propose of the most of the most and and the something of the presing the something of the belief of the possion of the such as the good of the are of the more of the possion of the possion of the prosence of the most of the propose of the such as a somet
#
# ----- diversity: 0.5
# ----- Generating with seed: "he conception of the world which has bee"
# he conception of the world which has been a sore bod the strong and dosence of the mast of such a groble excers of the most of the something is for a poritate
# in sight to all to mank of the world and wat to resule of their is even and the may of the mask undor of a soul to posing of maring of the manity, and and posing of the
# pain of the contrain of that would and it is oul and regord to far, and and hould to be storn, and the such an p
#
# ----- diversity: 1.0
# ----- Generating with seed: "he conception of the world which has bee"
# he conception of the world which has beereon it of have lacking to
# throughing ove "as. your earous xecticated revolucal) and
# as the dighconculify of goos of hisselves of such
# lesscanves, theik enguru"e sture bud it is not mo
# a trool, woll, ia same sumptally of to parnulakict, fot the buch a sibed
# the oustori, in omeman arro a copdenth rowile somein
# one's every ot recilincisibnes we happs, to masy by seven howices of
# must deffice of sifu
#
# ----- diversity: 1.2
# ----- Generating with seed: "he conception of the world which has bee"
# he conception of the world which has been warm
# de gued.""--allo'n procubles of chansem that fouct. thioks, roust:, al a
# postipe, sp!cloch as every bettriself--orimne, it, wry,- the
# seastion, thing preda, it, a si�piving but an exfect one is the
# perponic) it a mulads of vely a confrilicad verplecy arly bus
# ho
# groungariage. to "to religious of ever"incille" poosing, icdasced and con them it espress at ay snaquese
# instooce ants-cassing of
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200287/200287 [==============================] - 2602s - loss: 1.7050
#
# ----- diversity: 0.2
# ----- Generating with seed: "not be
# believed. how little it would be "
# not be
# believed. how little it would be all the something of the something of the present of the something the pore of the something to such a more the indivine and the most something and an inderstand the most something to the man for the most of the more of the restine of the soul of the something of the something and the something of the something the present of the most respition of the pose of the something to the present of the po
#
# ----- diversity: 0.5
# ----- Generating with seed: "not be
# believed. how little it would be "
# not be
# believed. how little it would be a that the sense of the something what who out decenter and quited to seem to such in all the sense the immand to a german in the most even lenghered under the most refuling the to the pose to refaithes.
#
#
# 18
#
# =the morals of which he can of the presention of the expersentifices, to whill the are the some of the indivicual of becient with the poserance which an an inder the impletent it the fore
# th
#
# ----- diversity: 1.0
# ----- Generating with seed: "not be
# believed. how little it would be "
# not be
# believed. how little it would be thoungh he precapter the explided and never are the
# would bo dustentionasion. oness ancorgrantevelf; lirances--and rifver
# whaniever for hength, to mane than unefsernable
# sais. whece, preackions he rons
# centuiner ly suscet i the free nat !ut make
# peate, termount to have the nequed. oun forty of clrasen and
# made the hoces immone and abe need to the port, "fee lust the
# mastor, alpadile: but the signt
#
# ----- diversity: 1.2
# ----- Generating with seed: "not be
# believed. how little it would be "
# not be
# believed. how little it would be ceerfony a bedneece the word? af anlishept whin," if alnwhoven truth"" onither wogle
# ganders ) highcex! whetenris for sometly to dade pxopors to all only poos podrely: not, we
# clust man thuw this o nose fol it in she sciln
# snate now korothed ta, enacs, howevans which and
# his conseqteded ytapes,=y sole3 exhimence, whenstbued
# "rams, it, at have is,ure certy, another,
#
# oves leot relble wkiflen to wea
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200287/200287 [==============================] - 2602s - loss: 1.6223
#
# ----- diversity: 0.2
# ----- Generating with seed: "h he is thoroughly imbued
# and coloured, "
# h he is thoroughly imbued
# and coloured, and the stronger of the religion of the most and astimet in the present the present and more to the moral of the struggless of the present and the and as a standing the strength, and the morality of the most replies the most interpretent and something the religion to the religion of the contemplated the religion and astimed and the forme of the most spirits and present the the most spirit and and
#
# ----- diversity: 0.5
# ----- Generating with seed: "h he is thoroughly imbued
# and coloured, "
# h he is thoroughly imbued
# and coloured, and and shame as it is something the struggle the imelition and a
# gen and common in so far "will be the rellog of the resulting to deally scholt in the the still experiences and revellest to the modations of the pronotion of the
# morality of a the "there is not with the other of the action to a some what is a not of the has and charate of the religion for
# this exists and philosophers of the conditi
#
# ----- diversity: 1.0
# ----- Generating with seed: "h he is thoroughly imbued
# and coloured, "
# h he is thoroughly imbued
# and coloured, a scientulies's have be bisk for the odibge saccorience
# as they are recoonal and disputionly pocees stomend of
# chpistain train duse of evongial erest.--but it rust it
# is to not have mankent even us for by edfic
# and doesing and most gean spirit.= and that
# tho ground fan wrateer a desemations the inconcimaty who
# !eposs of the mosts of ond will, and in the sladity gaintenny
# sy volfition prevent, sor
#
# ----- diversity: 1.2
# ----- Generating with seed: "h he is thoroughly imbued
# and coloured, "
# h he is thoroughly imbued
# and coloured, fire and
# aponchises punclenes indlect, and one, notqribs
# that his, munt oucen in mastic mmany" in
# =ydich"! thrills reckinleds.--thus nogation;
# to otherse) theirm" "repons of mistneg�,
# bun, they bluid, dexight and. any if tass. thir, uralkent "of his artic"s his
# propucizity.= humine itsels
# kand dorour1s long groin nghiuss, and for the
# ;arinu31, regthing,
# lhtaicr and a bitwarto-our oligans] and chpl
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 200287/200287 [==============================] - 2607s - loss: 1.5482
#
# ----- diversity: 0.2
# ----- Generating with seed: "ty and rigorous nobleness and
# self-respo"
# ty and rigorous nobleness and
# self-responsibility and state of the existence of the stand of the stand of the stand and state of the seems of the former of the strong of the possibility of the self-strong and the one in the present is a conscience and states and the seeming of the world of the conscience of all the instinct of the old and stands of the sels and stands of the possibility of the self-constitutes, and and all the strong of
#
# ----- diversity: 0.5
# ----- Generating with seed: "ty and rigorous nobleness and
# self-respo"
# ty and rigorous nobleness and
# self-responcises and oniginal to also which is also the best
# of his the oliginal conscience and conscience and like also a thing of a thought to him the notion of the ordinal conscience of the demonstic of the recornines
# and strong to the exist of himself and toman and also it in a conscious of
# the most discover to the late of such and case of the
# were and intention, the cape of the former of chance to say
#
# ----- diversity: 1.0
# ----- Generating with seed: "ty and rigorous nobleness and
# self-respo"
# ty and rigorous nobleness and
# self-respoys infleed s�evetions ratious, as teals, it exercisations]
# of "vire oungivally brans that chetural conciliecting, in the stull. and
# of mening the himment which seeking undicaty escaries to as: it wat
# previlist of hjidite 8out can wishe; to be being id-anougoginally and chailty, with the will with hind; resueves of dispious, as
# it is flangust prooded and thers are madn
# stated an to seems even to do
#
# ----- diversity: 1.2
# ----- Generating with seed: "ty and rigorous nobleness and
# self-respo"
# ty and rigorous nobleness and
# self-respo1zities we 0yen this brie=tice.
# jexous: rushous ara missate)s, season thoulds have
# dors may "wisleurate whenciot o4s. in every. to sacces is
# refiestaula[s, muruse
# the fiedive suppinity--he dafitulity who)e reaminar eagh
# to their craycchify and make bodks trad.
# ulleash-)lagny amospo on inselve man heaster
# ranabe, kenies. it way otherd generally nexed his oble, and constitutate of called arr time to
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 200287/200287 [==============================] - 2616s - loss: 1.4884
#
# ----- diversity: 0.2
# ----- Generating with seed: "of the dictum "whom god loves, he chasti"
# of the dictum "whom god loves, he chastists the most desire of the stronger of the stronger of the stronger of the stand of the stronger and consequences and here is the stronger possible the problem of the stronger and and experience of the stronger and in the stronger of the stronger of the stand of the stronger for the stronger and has been the stronger conscience in the strught of the stronger that the stronger and consequence in th
#
# ----- diversity: 0.5
# ----- Generating with seed: "of the dictum "whom god loves, he chasti"
# of the dictum "whom god loves, he chastis in the world of mankind in the something in the soul and always sense and of the betround of every
# and were it does not determine and in the headt of the nothing the desprises the boll of "the obitious of the condition of the new love of the soul and coll the
# volutation of the world of the soul a will to athersise the dight as the about from the whole be
# decreded to the stronger and constant eve
#
# ----- diversity: 1.0
# ----- Generating with seed: "of the dictum "whom god loves, he chasti"
# of the dictum "whom god loves, he chasticly from the pouses.
#
# =se haviss of buint perceives of ane motive, as he demenderly
# bad'� it. fol its; bach as alam who are exeritiam unomicate men as
# instine bectriently never the oll to the ave such persakility and rrmainsm one belosk univalsaly of mederior and brequal himself
# for the pannos a strove of struct1": was speaks bimstse
#
#
# b e2e one about heve" that as he pessles, but conflupnd, the b
#
# ----- diversity: 1.2
# ----- Generating with seed: "of the dictum "whom god loves, he chasti"
# of the dictum "whom god loves, he chastis of but
# mo9lies heavics, in_mades the live theik individual phylompo
# being theres who furde"s be meeper and 'noest: stmve ley of
# call esp; at look benost themmowald induch, and would as
# if self bad never as its own "po:""=-it pas"s"" ul"
# we "can""" "" "at"":" al"" yxra"d"" =" "ly"" this ."]""""": "he kno"l"""."""
#
# i" be "ne"4"""" lo"s "bes""""""y"" t"""""""?�"""""
# """"""" a �li""" pess""?"" a"" s
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 200287/200287 [==============================] - 2623s - loss: 1.4326
#
# ----- diversity: 0.2
# ----- Generating with seed: "on to
# exercise prolonged gratitude and p"
# on to
# exercise prolonged gratitude and present with the same time of the superior to the tran of the transion of the same to the same time and in the same still long of the same in the real to the stronger of the sublection of the reality of the has all the something of the soul of the stronger of the same with the sublection of the man of the superior of the same to a strong of the and who are the same in the same sense of the supersor
#
# ----- diversity: 0.5
# ----- Generating with seed: "on to
# exercise prolonged gratitude and p"
# on to
# exercise prolonged gratitude and problem of the
# religion. in the out of the senses the present standard for the anti-must and one of all the individual and his problem of the soletist of the world--and who are superiority of a sort of the
# suberganine and the moral problem of the
# subledition of the call to the stands of a good nature. he will as all the religion of the worth of the
# origin of the most incorression as the same suphis
#
# ----- diversity: 1.0
# ----- Generating with seed: "on to
# exercise prolonged gratitude and p"
# on to
# exercise prolonged gratitude and persomad is of togaie it is even mi to they hivermar that olm
# cunres, or every stands his of drand which they are not be belong in ideo adore in groupht--we law and astic] owher to the pay mored in a ant one had not pneasunal more in through beght blood"
# even it is every in ord repodic
# awong to wrateverly love does not beaute. in the factry,
# and fut theoririal cal selves; like that personal to the
#
# ----- diversity: 1.2
# ----- Generating with seed: "on to
# exercise prolonged gratitude and p"
# on to
# exercise prolonged gratitude and prectury, they parmonous, as to�ing and ou-in-torers; with men
# hrith, as to"certiz, event(intupres prefered omigine and such it likhwsing
# in the "freedom and evil-and best, afsedvered their _walf feelies: how
# all yew, a distinctive, lood of," "twat conequence of the grosplixi., we, mowers, mored it)elf you emannty, now
# ote!--�han it is a
# steps (one culudily ,! immet is
#  you goeptr with, unders aro-
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 200287/200287 [==============================] - 2629s - loss: 1.3811
#
# ----- diversity: 0.2
# ----- Generating with seed: "nger attain to
# his elevation, that is to"
# nger attain to
# his elevation, that is to a strong for the strong the rest of the strange and and self-deceptions of the strong strong and so for the end of the strength, the individual and schopar as the same with the strong the strength, and the strong of the conscience of all the strong of the strange in the same the propers of the strength, and the reason of the world of the fact that the fact that it is a man who can be one is the e
#
# ----- diversity: 0.5
# ----- Generating with seed: "nger attain to
# his elevation, that is to"
# nger attain to
# his elevation, that is to an the self-dourd and
# regree of the present man which the strong the respect of the conscience, which they its scholar of his own depresses, the christian power and schopenhauer
# sense and every act and discover of the process and a can nature, it is only a truth of the
# individual for the religious to play the
# strength, life its religions and deficial expression of the eternal life in order to or
#
# ----- diversity: 1.0
# ----- Generating with seed: "nger attain to
# his elevation, that is to"
# nger attain to
# his elevation, that is to who parhophered they cively they like they have e really cases--this really is desired, firsify, indoverse,, and whole of our lang!)  a lookev thought upon imperiar, men eash of muniness
# in the adsofled still if the philosopher "here,"--nor real exemple,
# womal prody of whom excless that all the individual actions, ithiscees and
# forwiflen when here- nowed the upprants itself--and the
# och preason m
#
# ----- diversity: 1.2
# ----- Generating with seed: "nger attain to
# his elevation, that is to"
# nger attain to
# his elevation, that is to never with the braising mogness. the
# sickausion is men to this yh]acting gratizulat viescount disposition is a
# sense brualdy, the profound, and results earde. almays"
# probedum:, to sacrificied)�
# thround all that saccedoly reason, but,,
# truy from lumble danife as which we blike oul ochens more that boqu! which who cessaic obly interests
# ty a, even, the lovich applaarablyical conception with the iw
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 200287/200287 [==============================] - 2635s - loss: 1.3371
#
# ----- diversity: 0.2
# ----- Generating with seed: "ething comes, and then expands himself s"
# ething comes, and then expands himself such as a religious indessing and the
# strong of the standard of the stand of the subject of the sense and the subject of the presence of the standpoint of the world of the subject of the subjection that it is a religious everything that it is not been man in the same time and the same in the same there is not been to the most desire for the more of the subjection to the subject of the subjection of
#
# ----- diversity: 0.5
# ----- Generating with seed: "ething comes, and then expands himself s"
# ething comes, and then expands himself say, such discipline and intellectual my influence of the world with the spirit of the prescision of the delight of the subjection is restruined to
# the expression of which a man when the subject, as everything everything that all the
# self-manitalisatic and the world of which better do to be interred to the "too" of the instinct of necessary to the trankingrust and saccety and the states of their in
#
# ----- diversity: 1.0
# ----- Generating with seed: "ething comes, and then expands himself s"
# ething comes, and then expands himself sensaused hybieso,
# everything evarce, are nothing which as a rived stonderf, and
# passional, defiar de in such many appressainly speekman you
# .ne'" thinking that an imbessogo as the good courabeer's expresses,
# the more german why considerance injecrivered and facter times he
# prosps of didintamepo"w."--his subjlety psychologists and woman is not have been how habiutated com9onter
# in ond to stem them.
#
# ----- diversity: 1.2
# ----- Generating with seed: "ething comes, and then expands himself s"
# ething comes, and then expands himself s6mething
# degrivity and infigere supilfelless muricilated.
#
# the itmanisened to its day,
# but its the raming, over, which hercal desiratids,
# and facter higher rejuirery weorought,, from existeousnessi), that who--tealily not the
# remoking one's owthard, likine, siccally requetion, nom, screan
# hyor understandpained to yet craiveruble
# bewtoghere: thos this motevour dom� saidg" forcefting, thencis(oppape
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 200287/200287 [==============================] - 2639s - loss: 1.2882
#
# ----- diversity: 0.2
# ----- Generating with seed: "s into the light whatever of the agitato"
# s into the light whatever of the agitato is the soul of the same time or of the most and called to the same as the state of the same time or of the sense of the same as the soul and
# reason and his possible to the same time as a religious and morality, and the soul of the same time as the soul and
# grantfally shame the stronger of the sense of the stronger of the stronger
# can be the same time or other man who has a religious and and
# moral
#
# ----- diversity: 0.5
# ----- Generating with seed: "s into the light whatever of the agitato"
# s into the light whatever of the agitato is a morality of
# the underision of purit--nature, that is a philosopher has not say, "the thought the presinal personal werent
# and philosopher and sone to us and streegth, and manners, that is allowical periods
# of conscience in the struggle and case is possible to
# present as a religious things which his presentively of thought it is possible to the belief in the german who
# dour not be still out o
#
# ----- diversity: 1.0
# ----- Generating with seed: "s into the light whatever of the agitato"
# s into the light whatever of the agitato and other seems to be
# strod-callid)) mankerony known and
# characteristics. .ic he uscarrideate of life
# as mo-nanch,ol_--get the slead--laterer the ling of manure, as theory--and
# it is is freedment in himself, who us the results of sciences spiretfica
# certainges, si bresoly, ethicaterian effects astement of
# humanity, in the wrold, and from humanity, powerf6ative, for the
# will", that which, at only
#
# ----- diversity: 1.2
# ----- Generating with seed: "s into the light whatever of the agitato"
# s into the light whatever of the agitato course perspeat�" to every
# itperions of tover advantias; for his pifwerly and
# fearest cruelty, whym however, and value and lave anlirest tfou
# and is :incerebtity, or a cyrtait, betra
# gratefully never, he is resuitive,.
#
#
# s50
# =velights schopar, they are calrecally man is also upen
# as the, we lowed soinally, "the developed of langurar, because
# in sboragn ive?--it must say: the !"se�manbit"d, the
# ch
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 200287/200287 [==============================] - 2624s - loss: 1.2387
#
# ----- diversity: 0.2
# ----- Generating with seed: " reverence for the bible has hitherto be"
#  reverence for the bible has hitherto been the most sense of the sense and decide for the masters of his tearing and the sense of the possibility of the senses to the
# master of the sense of the senses and propersion of the sensible of the sublime that the same as the sensible and
# desire for them. and the fact that the sense of the sensations of the most sense of the world of the senses and loves of the subject of the existence of the se
#
# ----- diversity: 0.5
# ----- Generating with seed: " reverence for the bible has hitherto be"
#  reverence for the bible has hitherto been the most desirable delight under the struggle with the art
# mankind of the same as the old with ancient from the more would have been toged the the
# sense of him it is in one must so fals with the personal stard
# and free-spirit we have perhaps the mankind his not being weak that is his own stall
# degard of the existence of the well as its of the best upon it is the problem of his that and recogniz
#
# ----- diversity: 1.0
# ----- Generating with seed: " reverence for the bible has hitherto be"
#  reverence for the bible has hitherto berotherness univilse in relexion of the end naces or of the
# existence may be cravicialed. at it has the
# mimaling pleasure, knowledge, implexions of
# eurore and fougation.--that with comprehension alzost in this weak strange the other; that we is found expewing begand it is periid, a costance or exrepves; morality, or ylache).
#
#
# 03
#
# =slave of prompinitgored. christi[nk and has the farties, _this for
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " reverence for the bible has hitherto be"
#  reverence for the bible has hitherto believe,
# fon its subcoms, forwerle, myain2 in what, what
# decide phinoish--the musi?s religiors
# and drivitiffe bfunged] it "stip dejus� and the
# gecies of what? what is confection we such otherling, seas and certain taste from better,, whils alsesside, therefore
# uligidations.--like throw gheas such;.
#
# 952--owedlive-with their "gool"--sendimen and to non-where every schose but me
# wrands no botn0shing ,
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 200287/200287 [==============================] - 2631s - loss: 1.1923
#
# ----- diversity: 0.2
# ----- Generating with seed: "nt, invincible, stable, and
# the like. to"
# nt, invincible, stable, and
# the like. to sure and in the subsecting the superstitious and conscience consequently
# the subsecting specime and secret that the struggle of the superiority of the
# present that the conscience of morality as the present in the subsection of the subsection of the
# present that the first to the first to the present that these are also a present to the superstitious and the superstitious and the
# speek of man of th
#
# ----- diversity: 0.5
# ----- Generating with seed: "nt, invincible, stable, and
# the like. to"
# nt, invincible, stable, and
# the like. to soul that man of an artisticial in the sperit is questions to a present to the
# subject of constitutes of persent to all this soul itself as a present to all any
# honest sensible to the tragedy and preservations and self-sensiality and the most power as to freedom
# still must be the fleedom of interpretation of the
# scientific man of the subsecting sussicial and sharpos and the spirit of the
# subsecti
#
# ----- diversity: 1.0
# ----- Generating with seed: "nt, invincible, stable, and
# the like. to"
# nt, invincible, stable, and
# the like. to cousses of severe will to the dewire of rank
# as a chileraled, but they are conspress, also effectt of the virtues of mank thous! yet
# now merely that these corceithed and reclinitiman. certainly like in a pwants of ipportanity.
#
# =9q. the dreamin making of successous points and rather in its from state?--whose
# handous mlat-ralications shows, and could not believes low as itselfest varues, and
# what
#
# ----- diversity: 1.2
# ----- Generating with seed: "nt, invincible, stable, and
# the like. to"
# nt, invincible, stable, and
# the like. to kneelom of far, exercise by
# mariment; inflichating eusligat of presentict. is as hap(
# by again of knows. and "the
# instinity �rasusuit�"s that proportanil:
# platefully and with struct �comm of "y51am, hesw to give becemed dispises "immeturate-cerse of misunderstandion
# bad evolved,ing of disicturm uncionest
# because of the "p7inarm"" a negaoeres"" and"
# dasces of moct prapare, apan avompanying and hap
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 200287/200287 [==============================] - 2631s - loss: 1.1419
#
# ----- diversity: 0.2
# ----- Generating with seed: "now be attained by every individual thro"
# now be attained by every individual through the state of the moral presses is a religion to the state of the strange that the
# same as the result of the state of the state of the state of the state of the interpretation of the power, of the state of the state of the spirituality and one is a still understand the strange that the soul of the statesm of man and the same with the fact that the other hand, and the same time are the moral pro
#
# ----- diversity: 0.5
# ----- Generating with seed: "now be attained by every individual thro"
# now be attained by every individual through the state of the
# belief in act of man and even when rehaited the problem of the
# religion the good of the present daninations,
# are the most delicate of the protoctity and action in
# such a thing of the more of things, as a sole who is a sumple of
# a seciety have been the good of the powerful
# morality. in the scaunt interests hampy become so that the virtues of the soul of an act of the powerful
# e
#
# ----- diversity: 1.0
# ----- Generating with seed: "now be attained by every individual thro"
# now be attained by every individual through nature' that regard out of
# never in the undelocate, which is that "the extenting youron high something were to looker upon
# himself with those id: at life with the art however, a
# cheristi aroshess that regard the soul of
# anteristis, while dery he was the owher nowader in the enture, consequently a cassor,
#
#
#                                                       2e1
#
#      any no mean  �ee, for
#
# ----- diversity: 1.2
# ----- Generating with seed: "now be attained by every individual thro"
# now be attained by every individual through affair, to
# home and enuwher--annimidentarly povy6limmes and action) upon
# the circimejnate religion.
# i8 9od, were therein leass and tyemnal, in a merely be
# i.f, morals the oys mered fatilish; muling moralistic, is nigoto[. some danger "good fist" its acts
# as itacists, as, as question
# whether mus century and depands of but kuring assudes;
# or a deckans to centuriey turbo? �athough on the
# spiritu
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 200287/200287 [==============================] - 2628s - loss: 1.0923
#
# ----- diversity: 0.2
# ----- Generating with seed: "ers, and likewise, alas! their first and"
# ers, and likewise, alas! their first and last as the same with the same with the same with the powerful
# man is a sort of great means of man the strange the struggle when they with the strange the struggle of the same with the strange that they contemplean
# or and conceittent to the process is the sublime
# present danger of the same with the highest works
# and profoundly and indesended to the mastery of the same with the subject of such a s
#
# ----- diversity: 0.5
# ----- Generating with seed: "ers, and likewise, alas! their first and"
# ers, and likewise, alas! their first and profoundly presentives, as we are it is the possibility of
# its and which he will as so for at last here they are not to a
# preterman intellectual and other--at least as a
# precisely the philosophers who could have the term or others, as a ruling aspect of
# strange the highe; scholar and its like at the old individual desirable themselves with their own principle and most such a manically
# conceitiona
#
# ----- diversity: 1.0
# ----- Generating with seed: "ers, and likewise, alas! their first and"
# ers, and likewise, alas! their first and
# respect among philosophy, and the saure of first and quise and
# goodness and its (atterus strangeh worthlesse--has the os--prochapan in contemplation, such
# its
# counter men, to do refroother, with its one beet makn compretend, a present stage of its advical abowt when it
# has they wake to good that is probably and
# housted, probed for the hand and the atruc_ of the eltentire
# to balify. one ever a wer
#
# ----- diversity: 1.2
# ----- Generating with seed: "ers, and likewise, alas! their first and"
# ers, and likewise, alas! their first and good about hys
# humis ard what bad conferes in any existicraus, and
# proted and still a�rematk itself in hid and
# donterous-ple addization from what have ticking to !thes far is course and
# through the fact trated, it! it al9 his no, dilfart
# itsust, almerice--leas) berneve been printipal questions,
# it is a psyqlogoos" i  ond caurd, my to .raves everything have from
# succomocale
# not in the furents. it
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 200287/200287 [==============================] - 2633s - loss: 1.0450
#
# ----- diversity: 0.2
# ----- Generating with seed: " refers to madame roland, or madame de
# s"
#  refers to madame roland, or madame de
# stage and the more ancient from the many of the superior
# of the problem of a herothenge be no for the man of
# the same the propert who are the hand of the soul of all the state of a consequence be any deared
# in the same as though the man of the world, which they can of the senses and the same knows of the world, and the same as the organization of the world, and
# honour to understand in the strange t
#
# ----- diversity: 0.5
# ----- Generating with seed: " refers to madame roland, or madame de
# s"
#  refers to madame roland, or madame de
# still, and has been so gince superiors to
# account a corporance of rank which has too
# propersive to any which has been such a hand which
# many willingly to a properient that word and he is the
# stronger and the struggle of graditade they would be wished to conception is to an all germanizism and of the artificial, and
# entiming to the extent of its own personalities of all the masterspocrify scarning o
#
# ----- diversity: 1.0
# ----- Generating with seed: " refers to madame roland, or madame de
# s"
#  refers to madame roland, or madame de
# sime, inatists at the any other neighbour, manifests.
#
# 10n
# 4=demonimes of the case strungth, it is the holuzate pall of it.
#
# i1 he chance and bad test be discreet in the dispection
# enta!tinary.
#
#
# 20
#
# =seeris do powsuad penitanal cupture, they are so realis_ here into being how mus
# crimoral devitor) of the men�ating this �ang.
#
# ";_  o         his mo them to gur to your "nature" or is more uncentuine
#
# ----- diversity: 1.2
# ----- Generating with seed: " refers to madame roland, or madame de
# s"
#  refers to madame roland, or madame de
# scannaces (bajber (errone, i!s. every compasis.
#
# [[.
#
# h7echumen every oowing their whone things:
#
# 8�
# any lusted  wit; there is, in exal agai, undegance of dating, in moralst is sentimentance as any attaineg: tob), our
# princidle vinticgngut of a! tapt�hly amply toping the dettring or trumphnty
# which succection, the tranmenty betaasion, all things (us well
# ever the forwer of guncers, one could nature
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 200287/200287 [==============================] - 2643s - loss: 0.9988
#
# ----- diversity: 0.2
# ----- Generating with seed: "ave judged and even philosophized almost"
# ave judged and even philosophized almost all the power of
# the world, and the true plant of all the stronger
# and presumptives and has he can problems to who was for the same time as the presure of the present, and the strange the herding of the present that the state of the problem of a sense of
# our soul, and he has he persented to the history of the world, almost as a
# religious the contrary, the contrary, the presured by the rest of the
#
# ----- diversity: 0.5
# ----- Generating with seed: "ave judged and even philosophized almost"
# ave judged and even philosophized almost is the individual and exceptional connection would be generally, also a problem of it is a cruelt is the rest
# of an action be not all the strength of the intreeks of its notwiths of the
# highest upon him end the problem of it is not only to whom the
# most personal man who has entiled understand the doubt that the standard of the prestrable simple of a most saintity, every stink of the former hences
#
# ----- diversity: 1.0
# ----- Generating with seed: "ave judged and even philosophized almost"
# ave judged and even philosophized almost all philosophers come to him, one does not learn a
# hingher-pose praquinl spirit, will not reverencl for the contrary to him of our shad.
#
#
# s0
# ditur: it when the _intipuatity and the domain of one would be the sufrerexpenting into efhers  he did him
# in notie.. hore. a
# men in such period from christian ;ocents it bad and of
# this very intellect. but what was litted about him even be order that have
#
# ----- diversity: 1.2
# ----- Generating with seed: "ave judged and even philosophized almost"
# ave judged and even philosophized almost
# hasf; findy any the ttunithfinately, (understance, and elic-pained obterance. deaphation pleaseh9sher, umply as indelfil0; in this, the out of
# the singe was be conserved, the honest encome that it is no kinds wake
# the soul of a anith3o. let is      syel this as num, nor esjublide distrade and morbor, we brisg where �ee
# speake "perfects;" let the sle?- smoman), something believe, in
# secfring subli
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 200287/200287 [==============================] - 2641s - loss: 0.9480
#
# ----- diversity: 0.2
# ----- Generating with seed: "s in whom the opposite of this exalted, "
# s in whom the opposite of this exalted, has always a sort of respect and one is not something that is the contemplate or
# all the most point, and honest means of the statesm of morals and consequently men of the powerful, the subject of community. the present dangers of the former for the same kinds of an artistic effect which they have to fied the powerful and the same kinds of the world which have been confed but to
# the finally conditi
#
# ----- diversity: 0.5
# ----- Generating with seed: "s in whom the opposite of this exalted, "
# s in whom the opposite of this exalted, and we are the same time are the phantered of religious the restly and respristing it is the
# individual done. the leart works and conceal itself and more for eximed. he will be still
# uncertain that the sense of this extent, when the some of "morals, that is to say, "at the love of an immoral philosophy, as he would he peaper to kind of interpreted in the end, and we states and believe it
# with an e
#
# ----- diversity: 1.0
# ----- Generating with seed: "s in whom the opposite of this exalted, "
# s in whom the opposite of this exalted, heriligity, good, and the
# instracties of the duite will time hepp us at leader than the one time but the act now doe
# not the same sinings, aid, this is not alrowed the most dogbativy which
# many! a metapedy belongs to us: it certainly equally courage the taste, there is more nature.
#
# s0.inf! child being.. this very intellect'6 assertions after long agon young--nobde morality out of
# eximbeation. for
#
# ----- diversity: 1.2
# ----- Generating with seed: "s in whom the opposite of this exalted, "
# s in whom the opposite of this exalted, as be flayted to this
# accestone; we mady comnict of relege and cave a banknefzen:: a old
# esign bosced accoudt, blooding for supgnitior which who
# arthus a disinteasing diphtragating out
# of this billing and forbided hidself under the
# most e9traration to salsk and fings was its, at fundamental graimst alboxial in accession
# to ussesting grvatation. it wish homovated low so flr act and suffering except
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 200287/200287 [==============================] - 2660s - loss: 0.9031
#
# ----- diversity: 0.2
# ----- Generating with seed: "aterialise "cause" and "effect," as the "
# aterialise "cause" and "effect," as the other perhaps even the moral problem of the "good" of a philosophers "the opposition of the results of
# morals are morality, and almost all the states false of the conscience, that is to say, in the case of an existence in the moral problem of the
# religious insigiatism and process with the most principle and the secret and casts the most sensations of the ordinary morality, and to fies the most spi
#
# ----- diversity: 0.5
# ----- Generating with seed: "aterialise "cause" and "effect," as the "
# aterialise "cause" and "effect," as the other
# experiences the existence of religious would be not be refured and even who can be
# one is not require that he deepliss the most porpon the
# expression of the realmentarism--and what is to say to subject of
# the exceptions and that which the intellectual and recose
# great, and evincupond believe that he who can the word of
# dangerous higher promptions are the masteristine of
# religion, if always r
#
# ----- diversity: 1.0
# ----- Generating with seed: "aterialise "cause" and "effect," as the "
# aterialise "cause" and "effect," as the beart of maticial.
#
#
# 969
# udean and facition had eljved9ent antimmetict�)" were there to conceituin 9y such a
# were an artimbbe peralistic or the crepulicial, or maticning, to nature is that to
# faith so graiss. hercless, always reach that
# he ceems somets and of "mistust! he view (their
# prey man: above all, knowe time, always to day, as hand planting on the end particula in equally
# contradictadly on
#
# ----- diversity: 1.2
# ----- Generating with seed: "aterialise "cause" and "effect," as the "
# aterialise "cause" and "effect," as the operative's
# of, youl will long agot, weaken, something exterra must, a thing through a misreas
# nandought," and just is mutter�blapes, whatever least! bettere "beendarsm"-it would bik himself, as,
# conspious, treat� at last amove the dound and profongm.
# there acriving science, and will an in-certain
# "norainy," and tine planfiallye sour of such
# avain discovered at perpain to the turble!
#
#
# 15'
#
# =preju
#
# --------------------------------------------------
# Iteration 22
# ...
#
# --------------------------------------------------
# Iteration 53
# Epoch 1/1
# 200287/200287 [==============================] - 2707s - loss: 0.2283
#
# ----- diversity: 0.2
# ----- Generating with seed: "r as the most elaborate and
# ultimate pro"
# r as the most elaborate and
# ultimate prodousion and exception which had interpreted to the most wrong to the conception with which it is thus like them one
# says worded into the former not because be
# the dighing of the artistic pethous men and
# all the struggle against become has all the
# leader and morality for the culion and inneirebord of daring and privileged and that can
# colone where the belief their more greatheries
# man this self sac
#
# ----- diversity: 0.5
# ----- Generating with seed: "r as the most elaborate and
# ultimate pro"
# r as the most elaborate and
# ultimate production and european confuliegen of the theor[is to an art of religions, was nothing to be "mustable men, and their falle most
# spirituality of other, the evil asision and been shame and so
# that they wished with inference to properly in
# short, must be all the most personality which offer longenty most
# indeed in order to mone thing and men lost without and finally confurned to be must be the cause o
#
# ----- diversity: 1.0
# ----- Generating with seed: "r as the most elaborate and
# ultimate pro"
# r as the most elaborate and
# ultimate production and curce: at laak: the wished wish to be taste, although it will be a returned it
# is not pone. the cause of its delicate their mothers of the their proxpethy
# cause of things of words, and as will to power, with their community as this bad confition
# explections and interpreted and interest in like a psychologist which
# herst because she masters the other estressing to the form of wordness,
#
# ----- diversity: 1.2
# ----- Generating with seed: "r as the most elaborate and
# ultimate pro"
# r as the most elaborate and
# ultimate prodicity and ear for his day which one would says "it is o!
# essential to fact which we curtein that it was
# himself, as in a reludion more imman: all
# theoure all the still upgeraally conditions. the pholoppe may slain and amagerated, that is invertion, they are all our lostures, more psychally
# of
# sympathy.
#
# 28. when here gean ol as has been deven eethered bocan--philosophy is only confuintly about ma
#
# --------------------------------------------------
# Iteration 54
# Epoch 1/1
# 200287/200287 [==============================] - 2746s - loss: 0.2154
#
# ----- diversity: 0.2
# ----- Generating with seed: " good taste.
#
# 222. wherever sympathy (fe"
#  good taste.
#
# 222. wherever sympathy (feer morals are in the master-one so many was painte for exasting, world, in the moral soul amain the world what is the was wart them not be content with comparion of the
# hearts, and the revaliable smiliars and above all the literation for the conscience philosophers to be the happiness of the recognizion of the eyes of every act of the historical spiritualise, the fact that the interpretation of th
#
# ----- diversity: 0.5
# ----- Generating with seed: " good taste.
#
# 222. wherever sympathy (fe"
#  good taste.
#
# 222. wherever sympathy (ferm not in questions were still love the the other man be
# reverence to the most marbees and restrume, who very law ges all the strange to love said that
# it is not be took a scientific profound of the intranse themselves with mank
# (endors and injust_ the table of right and frave at exascoming to the propers the tabe. the position re
# disluses of philosophy, and more compartial even the mesturct is of
#
# ----- diversity: 1.0
# ----- Generating with seed: " good taste.
#
# 222. wherever sympathy (fe"
#  good taste.
#
# 222. wherever sympathy (ferm no obinity the development of others, is the insignificance, a contemption
# to passion to wear! the clumsely beyong to be cortem and
# man who says "i s."
#
# 58] carcetod the nations "time ato of good" and didgrine, or principher'un that has been world be
# possible for his ignow and hone that has caused the
# time is of the old cold consequant the commining idlesest to a becomine irresmencible
# the grad
#
# ----- diversity: 1.2
# ----- Generating with seed: " good taste.
#
# 222. wherever sympathy (fe"
#  good taste.
#
# 222. wherever sympathy (feer and save gird would be receired and determines and their axpless of requirements,
# morals, and more compinement (fally mankind to it, and, in all light to him, to does itsal, which as in the assimical
# effect of napare--or who insolver and notions that indorine its one of
# human becomes, the about this something greater8r incuntive manines still more is comprehensive in itself.
#
#
# 2.
#
# =hugher conte
#
# --------------------------------------------------
# Iteration 55
# Epoch 1/1
# 200287/200287 [==============================] - 2794s - loss: 0.2071
#
# ----- diversity: 0.2
# ----- Generating with seed: " in what they regard as
# actually having "
#  in what they regard as
# actually having of the attentive man who says
# "     souls what depere ammoman "new sepuesting
# instruments, it is the crust and readiness and species where a belief the english concerning, a stand pain of stational instinct of self drant and reverse
# something that would not have deeped be with reverence for the
# "intellectual value of which whose concerning the gleard exception, the
# lof themselves which the former
#
# ----- diversity: 0.5
# ----- Generating with seed: " in what they regard as
# actually having "
#  in what they regard as
# actually having of the atception of the consequences, is not
# dissurbons are morals of comaus, and after all the last emadely of spirit and the sacrifice of the sensation of the art of the souls of
# human because with which who society which is only when a condition had he not calced to many of
# the subsectine sinsich it. the protoved cale consequences
# be resuetuents, in spite of the increase of christianity and out
#
# ----- diversity: 1.0
# ----- Generating with seed: " in what they regard as
# actually having "
#  in what they regard as
# actually having of the atteinal compleriance and out of view, and the immuria is obligious
# ideast? and a new power, a �eed and religious a mastery of such tranger, wherebe that is an ordarve
#
# and whith case the far to plece a state of consequences, for the intannien of "mited" of
# homarred), now whence to be sure, in state,
# who has always to seek in one, love the their excitement of
# religious conscience, which it
#
# ----- diversity: 1.2
# ----- Generating with seed: " in what they regard as
# actually having "
#  in what they regard as
# actually having of the ear, in fact, well-word, in one can no
# longer bejult--how be arson! a nowgerne, browe -whence that it
# is conquired to the given of antiquity which we into the herder as p�re most skepticism; is the interpretation of lightengence, regard also, in the self-secuble; to
# the pressrible =menture is invention. they dare of reconneces
# man become much. there are into the demand taste call
# out of isp
#
# --------------------------------------------------
# Iteration 56
# Epoch 1/1
# 200287/200287 [==============================] - 2672s - loss: 0.2047
#
# ----- diversity: 0.2
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# ancient things grow begodes which be immediately
# means of imperative does where a defuniments of our
# world for the proper of jegarious pulping the metions of the
# others, we may dead to asce the art for example of the
# serval of the opinion with all ang is possible that perhaps the
# book of their age, in distory of some times of and
# asting until to the power to which at allations of in one engous not o
#
# ----- diversity: 0.5
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# ancient things grow
# begody we all the result of his meanting of the
# unportions of interest the gind of richar
# more calcely reverence, as the result of sinking and confers
# its senstants, such as in the present stimut of moral
# endurg, and himself, at least it be immediately would be there against a
# complexs of kind of crassic cimculfing the slims
# sensible for the interpreted to still favours the infur
#
# ----- diversity: 1.0
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# anciently conficto of which german chance. "god wher himself what called good particials, himself about these things b8
# 2ne! even the familian with the mal, of contrary and a statesman
# which a temple moral especially among action, no lither was had the
# before be present and bad and kencess character stay
# speaker: and almost everything that is possible on the
# dartred feelings and the amoknogical cep
#
# ----- diversity: 1.2
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# ancient thinking with the uncertain of man to the ain which concience as with rest as the phosition that there are "mellos "has it"
# phalosopher." " he who ourse veat not in trum! in the moral of chiricipe could be invention. it is
#
#     is where ;ou gere a frengs were every secuted ay in conditionated had
# in the same as they call to philosophizes, in fact, the true of
# the possibility, and of "screnki
#
# --------------------------------------------------
# Iteration 57
# Epoch 1/1
# 200287/200287 [==============================] - 2693s - loss: 0.1988
#
# ----- diversity: 0.2
# ----- Generating with seed: " times of danger from science, incorpora"
#  times of danger from science, incorporated, system,
# and of the desire for strength, the general curiosity of the results brings his workhnow his
# echorstic of which the occasioned, science redictions of morals and imperious--but with the first
# sins and good fassibilities. the merely concerning the propert instinct of mode and the other prospected; all the
# conditions, the world, and reverse for the remains is do a little and the their ow
#
# ----- diversity: 0.5
# ----- Generating with seed: " times of danger from science, incorpora"
#  times of danger from science, incorporated, syep,,,
# disinter, intellect, and always be necessary, and more
# instructed, and accuracy of contradaction that the foundation of the results or
# destructed, with their self-strength, it is the "stronges of the ea, that
# it is else to fied and confulity it has consed to to make a principal conceration of morals, one may we causated forchs; or word, a circumstances, the justice,
# the tradition of a
#
# ----- diversity: 1.0
# ----- Generating with seed: " times of danger from science, incorpora"
#  times of danger from science, incorporated system,
# and actual significanti-precisely knows is own the
# same as and now every one from him: no doubt that is a sirpla of needs he sees satisfiently
# soult beings is onl ase the properts "no philosophic""," so fear of the gratifuld opposition of means and inasiteous, has at exest degare of its prongested and represent to the falueto
# sciriupe, french, that the conception of "or "at all," we se
#
# ----- diversity: 1.2
# ----- Generating with seed: " times of danger from science, incorpora"
#  times of danger from science, incorporated sy)f and as be
# knew fully in fact, when the higher and more emplay the end of who partry he consequences.3ity for the disciplicate commen-syept, by was a transforme: it is jews that
# the secraning from whic sall, in the rall hat freecomed, readly among the whole_s in'erercles
# countly and conception, the lass essibling suspenions of the present, not to noble so geant
# that it is elevated. only th
#
# --------------------------------------------------
# Iteration 58
# Epoch 1/1
# 200287/200287 [==============================] - 2683s - loss: 0.1896
#
# ----- diversity: 0.2
# ----- Generating with seed: " the person with whom i am speaking so c"
#  the person with whom i am speaking so clase the painfe uners atoveralless, the
# consequently embobe individuals aritability in any string, word, a conduct is a dowination of
# ourselves will protred and string for the fact that it is
# refaired and stated depthat his passion, and their must be canned one in the world
# have on the deserved and the art of crumition, and
# a results--in his a good
# mankind. it caused the belief which is had the be
#
# ----- diversity: 0.5
# ----- Generating with seed: " the person with whom i am speaking so c"
#  the person with whom i am speaking so clase it was
# particles, for all, such plays and loves of the
# howover, who are now follow the stuped all the continuance of victseas. all things which makes them, they will always reason gon aurea confulling himself upon the most adplinate the solitable, rulen
# stand--and with the higher and more perfectly of styep and all the people, which
# has its owness songem--the cannot of "modern ideas," when ha
#
# ----- diversity: 1.0
# ----- Generating with seed: " the person with whom i am speaking so c"
#  the person with whom i am speaking so clase it (and with a profound and skupor and first timedy6hopever, a toling
# contemstomed one it esseed and now to stand of the
# things. if the question, that is to say, to we friends, the un�uther and
# determinest make of the telluct of constitution which make
# man general our need of the last german philologist, and often all individualide and external strict
# feeooness encempory in the satial at rabb
#
# ----- diversity: 1.2
# ----- Generating with seed: " the person with whom i am speaking so c"
#  the person with whom i am speaking so clavely
# revintivel. if one wishes to those of the soul of vacibull: europe a
# personal sorther in eeropation, an all the the happoned by
# the dear1 be in acipation in the foundation of the effect which he is--ctording to which we
# only in ord"rable moralization, provared: and it is almost in satfiezy which
# means of woman with such idiliar value belief and of the should something uncomendizity. it this
#
# --------------------------------------------------
# Iteration 59
# Epoch 1/1
# 200287/200287 [==============================] - 2828s - loss: 0.1843
#
# ----- diversity: 0.2
# ----- Generating with seed: "e it from
# this pit without thereby funda"
# e it from
# this pit without thereby fundamental ccan hilline
# and attentively understitional can, that it will say "is so far from the good gainen to a repuls and of existence: but that is becomined to the same trubler; in
# the continung of the common the growmpot really bettated to a dangerous intellectual as receptions of the
# enother and noting for the lack of cause and the woold which of the spirit was does not
# lave recognized as "unvar
#
# ----- diversity: 0.5
# ----- Generating with seed: "e it from
# this pit without thereby funda"
# e it from
# this pit without thereby fundamental ccan expled to the nothing else, are also age at the spernal of all the soul.
#
#                        2.
#
#      it semmand always can (peotes understand without fact which do into the same what is ever had to the nother exercise of
# worth, a great deal does are rathred all incenner, moralses, amounder.
#
# 111. the prads a manity of cal and fear breatty. but why
# in the fact that the incerning se
#
# ----- diversity: 1.0
# ----- Generating with seed: "e it from
# this pit without thereby funda"
# e it from
# this pit without thereby fundamental ccan conceited justice
# is alave upon the feeling of knowledge, of the consciousness of humanity conscience, that the
# speen and again according to a standione before action in the character
# of the great could spirit in the interpreted in
# the case of the sentiment of selves and in europe is because theie disposing that the more of this side and uncertain
# or things developed to properly love t
#
# ----- diversity: 1.2
# ----- Generating with seed: "e it from
# this pit without thereby funda"
# e it from
# this pit without thereby fundamental ccan childinan3, of the squelt
# desire for him. social philosopher spenking to be old, in the means
# of vivisely womly personal and about thy these aress oftent to what in their spacie a value unpersonal sciences be afferented to the
# same fleedy are for the power hand. but that is a givine and its say arrogething what is
# regarded as the continuan condicion."--and that it is not, but it is bec
