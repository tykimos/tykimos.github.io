# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 28
width = 28
channels = 1

A_generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(128 * 14 * 14)(A_generator_input)
x = layers.LeakyReLU()(x)                       
x = layers.Reshape((14, 14, 128))(x)            

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)     
x = layers.LeakyReLU()(x)                                            

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x) 
A_generator = keras.models.Model(A_generator_input, x)                   
A_generator.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25088)             827904
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 25088)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         12545
# =================================================================
# Total params: 5,986,049
# Trainable params: 5,986,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
B_generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(128 * 14 * 14)(B_generator_input)
x = layers.LeakyReLU()(x)                       
x = layers.Reshape((14, 14, 128))(x)            

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)     
x = layers.LeakyReLU()(x)                                            

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x) 
B_generator = keras.models.Model(B_generator_input, x)                   
B_generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25088)             827904
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 25088)             0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 256)       819456
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 1)         12545
# =================================================================
# Total params: 5,986,049
# Trainable params: 5,986,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
C_generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(128 * 14 * 14)(C_generator_input)
x = layers.LeakyReLU()(x)                       
x = layers.Reshape((14, 14, 128))(x)            

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)     
x = layers.LeakyReLU()(x)                                            

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x) 
C_generator = keras.models.Model(C_generator_input, x)                   
C_generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25088)             827904
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 25088)             0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 256)       819456
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 1)         12545
# =================================================================
# Total params: 5,986,049
# Trainable params: 5,986,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
A_discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(A_discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)                                      

#x = layers.Dense(1, activation='sigmoid')(x)                    
x = layers.Dense(1, activation='linear')(x)

A_discriminator = keras.models.Model(A_discriminator_input, x)      
A_discriminator.summary()

A_discriminator_optimizer = keras.optimizers.RMSprop(
    lr=0.0008,
    clipvalue=1.0,                                              
    decay=1e-8)                                                 
# dog_discriminator.compile(optimizer=dog_discriminator_optimizer, loss='binary_crossentropy')
A_discriminator.compile(optimizer=A_discriminator_optimizer, loss='mse')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 26, 26, 128)       1280
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 12, 12, 128)       262272
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 5, 128)         262272
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 1, 1, 128)         262272
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 788,225
# Trainable params: 788,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
B_discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(B_discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)                                      

#x = layers.Dense(1, activation='sigmoid')(x)                    
x = layers.Dense(1, activation='linear')(x)                    

B_discriminator = keras.models.Model(B_discriminator_input, x)      
B_discriminator.summary()

B_discriminator_optimizer = keras.optimizers.RMSprop(
    lr=0.0008,
    clipvalue=1.0,                                              
    decay=1e-8)                                                 
#bird_discriminator.compile(optimizer=bird_discriminator_optimizer, loss='binary_crossentropy')
B_discriminator.compile(optimizer=B_discriminator_optimizer, loss='mse')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 26, 26, 128)       1280
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 12, 12, 128)       262272
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 5, 5, 128)         262272
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 1, 1, 128)         262272
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 788,225
# Trainable params: 788,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
A_discriminator.trainable = False                       

A_gan_input = keras.Input(shape=(latent_dim,))
A_gan_output = A_discriminator(A_generator(A_gan_input))
A_gan = keras.models.Model(A_gan_input, A_gan_output)

A_gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
#dog_gan.compile(optimizer=dog_gan_optimizer, loss='binary_crossentropy')
A_gan.compile(optimizer=A_gan_optimizer, loss='mse')

# %%
B_discriminator.trainable = False                       

B_gan_input = keras.Input(shape=(latent_dim,))
B_gan_output = B_discriminator(B_generator(B_gan_input))
B_gan = keras.models.Model(B_gan_input, B_gan_output)

B_gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
#bird_gan.compile(optimizer=bird_gan_optimizer, loss='binary_crossentropy')
B_gan.compile(optimizer=B_gan_optimizer, loss='mse')

# %%
C_gan_input = keras.Input(shape=(latent_dim,))

C_gen = C_generator(C_gan_input)

C_gan_output_A = A_discriminator(C_gen)
C_gan_output_B = B_discriminator(C_gen)

C_gan = keras.models.Model(C_gan_input, outputs = [C_gan_output_A, C_gan_output_B])

C_gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
#composite_gan.compile(optimizer=composite_gan_optimizer, loss='binary_crossentropy', loss_weights=[1., 1.])
C_gan.compile(optimizer=C_gan_optimizer, loss='mse', loss_weights=[1., 1.])

C_gan.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_8 (InputLayer)             (None, 32)            0
# ____________________________________________________________________________________________________
# model_3 (Model)                  (None, 28, 28, 1)     5986049     input_8[0][0]
# ____________________________________________________________________________________________________
# model_4 (Model)                  (None, 1)             788225      model_3[1][0]
# ____________________________________________________________________________________________________
# model_5 (Model)                  (None, 1)             788225      model_3[1][0]
# ====================================================================================================
# Total params: 7,562,499
# Trainable params: 5,986,049
# Non-trainable params: 1,576,450
# ____________________________________________________________________________________________________

# %%
import os
from keras.preprocessing import image

#(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data() 
(x_train, y_train), (_, _) = keras.datasets.mnist.load_data() 

A_x_train = x_train[y_train.flatten() == 1] # 1
B_x_train = x_train[y_train.flatten() == 8] # 8

A_x_train = A_x_train.reshape(
    (A_x_train.shape[0],) +                                       
    (height, width, channels)).astype('float32') / 255.         

B_x_train = B_x_train.reshape(
    (B_x_train.shape[0],) +                                       
    (height, width, channels)).astype('float32') / 255.         

iterations = 10000
batch_size = 20
save_dir = 'warehouse/cp_gan/'

# %%
start = 0
for step in range(iterations):

    stop = start + batch_size               
    
    # A_discr
    A_random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    A_generated_images = A_generator.predict(A_random_latent_vectors) 
    A_real_images = A_x_train[start: stop]                          
    A_combined_images = np.concatenate([A_generated_images, A_real_images])      
    A_labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])                   
    A_labels += 0.05 * np.random.random(A_labels.shape)                        

    A_d_loss = A_discriminator.train_on_batch(A_combined_images, A_labels)

    # A_gan
        
    A_random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))                   
    A_misleading_targets = np.zeros((batch_size, 1))
    
    A_a_loss = A_gan.train_on_batch(A_random_latent_vectors, A_misleading_targets)

    # bird_discr
    B_random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))        
    B_generated_images = B_generator.predict(B_random_latent_vectors) 
    B_real_images = B_x_train[start: stop]                          
    B_combined_images = np.concatenate([B_generated_images, B_real_images])      
    B_labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])                   
    B_labels += 0.05 * np.random.random(B_labels.shape)

    B_d_loss = B_discriminator.train_on_batch(B_combined_images, B_labels) 

    # bird_gan
    B_random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))                   
    B_misleading_targets = np.zeros((batch_size, 1))
    
    B_a_loss = B_gan.train_on_batch(B_random_latent_vectors, B_misleading_targets)                            
    
    C_random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))        
    C_generated_images = C_generator.predict(C_random_latent_vectors) 
    
    # dogbird_gan 
    
    A_combined_images = np.concatenate([C_generated_images, A_real_images])
    A_labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
    A_labels += 0.05 * np.random.random(A_labels.shape)

    B_combined_images = np.concatenate([C_generated_images, B_real_images])
    B_labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
    B_labels += 0.05 * np.random.random(B_labels.shape)

    AC_d_loss = A_discriminator.train_on_batch(A_combined_images, A_labels)
    BC_d_loss = B_discriminator.train_on_batch(B_combined_images, B_labels)

    C_random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))                   
    C_misleading_targets = np.zeros((batch_size, 1))
    
    C_a_loss = C_gan.train_on_batch(C_random_latent_vectors, [C_misleading_targets, C_misleading_targets])
    
    start += batch_size
    if start > min([len(A_x_train), len(B_x_train)]) - batch_size:
        start = 0
    if step % 100 == 0:                                                    

        #A_gan.save_weights('A_gan.h5')                                         
        #B_gan.save_weights('B_gan.h5')                                         
        #C_gan.save_weights('C_gan.h5')                                         

        print('A_discriminator loss:', A_d_loss)                               
        print('A_adversarial loss:', A_a_loss)                                 

        print('B_discriminator loss:', B_d_loss)                               
        print('B_adversarial loss:', B_a_loss)                                 

        print('AC_discriminator loss:', AC_d_loss)                               
        print('BC_discriminator loss:', BC_d_loss)                                       
        print('C_adversarial loss:', C_a_loss)                                         

        A_img = image.array_to_img(A_generated_images[0] * 255., scale=False)  
        A_img.save(os.path.join(save_dir, 'generated_A' + str(step) + '.png'))              
        A_img = image.array_to_img(A_real_images[0] * 255., scale=False)       
        A_img.save(os.path.join(save_dir, 'real_A' + str(step) + '.png'))                   
        
        B_img = image.array_to_img(B_generated_images[0] * 255., scale=False)  
        B_img.save(os.path.join(save_dir, 'generated_B' + str(step) + '.png'))              
        B_img = image.array_to_img(B_real_images[0] * 255., scale=False)       
        B_img.save(os.path.join(save_dir, 'real_B' + str(step) + '.png'))                   
        
        C_img = image.array_to_img(C_generated_images[0] * 255., scale=False)  
        C_img.save(os.path.join(save_dir, 'generated_C' + str(step) + '.png'))
# Out:
# ('A_discriminator loss:', 0.5319562)
# ('A_adversarial loss:', 0.022552082)
# ('B_discriminator loss:', 0.52579385)
# ('B_adversarial loss:', 0.03546444)
# ('AC_discriminator loss:', 2.0682008)
# ('BC_discriminator loss:', 2.2550111)
# ('C_adversarial loss:', [0.011646757, 0.0013579477, 0.010288809])
# ('A_discriminator loss:', 0.12533802)
# ('A_adversarial loss:', 0.44669876)
# ('B_discriminator loss:', 0.081568599)
# ('B_adversarial loss:', 2.3588853)
# ('AC_discriminator loss:', 0.3089149)
# ('BC_discriminator loss:', 0.27823326)
# ('C_adversarial loss:', [0.48539141, 0.42829531, 0.057096083])
# ('A_discriminator loss:', 0.11360258)
# ('A_adversarial loss:', 0.89114302)
# ('B_discriminator loss:', 0.28869873)
# ('B_adversarial loss:', 0.78756338)
# ('AC_discriminator loss:', 0.085388206)
# ('BC_discriminator loss:', 0.10025349)
# ('C_adversarial loss:', [1.7419262, 0.83763772, 0.90428841])
# ('A_discriminator loss:', 0.20880584)
# ('A_adversarial loss:', 0.49677247)
# ('B_discriminator loss:', 0.19386016)
# ('B_adversarial loss:', 1.2755191)
# ('AC_discriminator loss:', 0.045825079)
# ('BC_discriminator loss:', 0.26520655)
# ('C_adversarial loss:', [0.96713167, 0.85291195, 0.1142197])
# ('A_discriminator loss:', 0.18446627)
# ('A_adversarial loss:', 0.25406483)
# ('B_discriminator loss:', 0.091088764)
# ('B_adversarial loss:', 1.6323439)
# ('AC_discriminator loss:', 0.1196758)
# ('BC_discriminator loss:', 0.088705197)
# ('C_adversarial loss:', [1.5489175, 1.4313352, 0.11758238])
# ('A_discriminator loss:', 0.098278441)
# ('A_adversarial loss:', 1.1450375)
# ('B_discriminator loss:', 0.13786833)
# ('B_adversarial loss:', 2.1534615)
# ('AC_discriminator loss:', 0.089180849)
# ('BC_discriminator loss:', 0.16031949)
# ('C_adversarial loss:', [1.3362848, 0.74890625, 0.5873785])
# ('A_discriminator loss:', 0.1955215)
# ('A_adversarial loss:', 1.3516353)
# ('B_discriminator loss:', 0.15451398)
# ('B_adversarial loss:', 0.20755109)
# ('AC_discriminator loss:', 0.29802346)
# ('BC_discriminator loss:', 0.067038171)
# ('C_adversarial loss:', [1.5650924, 0.26132751, 1.3037649])
# ('A_discriminator loss:', 0.058730699)
# ('A_adversarial loss:', 0.83335769)
# ('B_discriminator loss:', 0.062590569)
# ('B_adversarial loss:', 1.6542253)
# ('AC_discriminator loss:', 0.027055334)
# ('BC_discriminator loss:', 0.19133684)
# ('C_adversarial loss:', [2.2177076, 0.82502621, 1.3926814])
# ('A_discriminator loss:', 0.22621331)
# ('A_adversarial loss:', 0.89222896)
# ('B_discriminator loss:', 0.24162786)
# ('B_adversarial loss:', 0.34186515)
# ('AC_discriminator loss:', 0.10936914)
# ('BC_discriminator loss:', 0.10654499)
# ('C_adversarial loss:', [1.4209861, 0.71702111, 0.70396495])
# ('A_discriminator loss:', 0.15356633)
# ('A_adversarial loss:', 1.4526061)
# ('B_discriminator loss:', 0.19628033)
# ('B_adversarial loss:', 0.76069081)
# ('AC_discriminator loss:', 0.11931872)
# ('BC_discriminator loss:', 0.063105121)
# ('C_adversarial loss:', [0.90284503, 0.26460385, 0.63824117])
# ('A_discriminator loss:', 0.12895317)
# ('A_adversarial loss:', 1.1467493)
# ('B_discriminator loss:', 0.067449667)
# ('B_adversarial loss:', 0.93070924)
# ('AC_discriminator loss:', 0.13827357)
# ('BC_discriminator loss:', 0.093787447)
# ('C_adversarial loss:', [2.1870749, 0.46396676, 1.7231081])
# ('A_discriminator loss:', 0.049204011)
# ('A_adversarial loss:', 1.3397095)
# ('B_discriminator loss:', 0.062933877)
# ('B_adversarial loss:', 1.4107378)
# ('AC_discriminator loss:', 0.048055004)
# ('BC_discriminator loss:', 0.065039672)
# ('C_adversarial loss:', [0.95590746, 0.50987315, 0.44603434])
# ('A_discriminator loss:', 0.068520024)
# ('A_adversarial loss:', 1.1244291)
# ('B_discriminator loss:', 0.051003732)
# ('B_adversarial loss:', 1.4585226)
# ('AC_discriminator loss:', 0.10018916)
# ('BC_discriminator loss:', 0.22805324)
# ('C_adversarial loss:', [0.78357738, 0.52309674, 0.26048064])
# ('A_discriminator loss:', 0.06376531)
# ('A_adversarial loss:', 0.84849548)
# ('B_discriminator loss:', 0.098233774)
# ('B_adversarial loss:', 1.1891816)
# ('AC_discriminator loss:', 0.023781639)
# ('BC_discriminator loss:', 0.073318221)
# ('C_adversarial loss:', [1.5336564, 0.81803513, 0.71562129])
# ('A_discriminator loss:', 0.034492247)
# ('A_adversarial loss:', 1.1810091)
# ('B_discriminator loss:', 0.1347279)
# ('B_adversarial loss:', 1.0303895)
# ('AC_discriminator loss:', 0.037120055)
# ('BC_discriminator loss:', 0.15975568)
# ('C_adversarial loss:', [1.2588542, 0.62307608, 0.63577813])
# ('A_discriminator loss:', 0.6855756)
# ('A_adversarial loss:', 5.6108289)
# ('B_discriminator loss:', 0.064710587)
# ('B_adversarial loss:', 0.79764515)
# ('AC_discriminator loss:', 0.056430809)
# ('BC_discriminator loss:', 0.055632554)
# ('C_adversarial loss:', [1.9759988, 1.0607827, 0.91521609])
# ('A_discriminator loss:', 0.072240449)
# ('A_adversarial loss:', 1.1450628)
# ('B_discriminator loss:', 0.16102341)
# ('B_adversarial loss:', 0.66024578)
# ('AC_discriminator loss:', 0.036709659)
# ('BC_discriminator loss:', 0.077904746)
# ('C_adversarial loss:', [1.2966511, 0.69373548, 0.60291564])
# ('A_discriminator loss:', 0.024144467)
# ('A_adversarial loss:', 1.30038)
# ('B_discriminator loss:', 0.058783311)
# ('B_adversarial loss:', 0.63523662)
# ('AC_discriminator loss:', 0.02225489)
# ('BC_discriminator loss:', 0.021316934)
# ('C_adversarial loss:', [1.4059553, 0.62280476, 0.78315055])
# ('A_discriminator loss:', 0.11555145)
# ('A_adversarial loss:', 1.015336)
# ('B_discriminator loss:', 0.077349924)
# ('B_adversarial loss:', 1.4332142)
# ('AC_discriminator loss:', 0.11952957)
# ('BC_discriminator loss:', 0.19557658)
# ('C_adversarial loss:', [0.72140014, 0.43831959, 0.28308052])
# ('A_discriminator loss:', 0.016506815)
# ('A_adversarial loss:', 1.5709168)
# ('B_discriminator loss:', 0.13235427)
# ('B_adversarial loss:', 0.55590409)
# ('AC_discriminator loss:', 0.045729391)
# ('BC_discriminator loss:', 0.057026796)
# ('C_adversarial loss:', [1.9684918, 0.61617929, 1.3523124])
# ('A_discriminator loss:', 0.032787807)
# ('A_adversarial loss:', 0.93733537)
# ('B_discriminator loss:', 0.078516901)
# ('B_adversarial loss:', 0.6242615)
# ('AC_discriminator loss:', 0.024118915)
# ('BC_discriminator loss:', 0.035798155)
# ('C_adversarial loss:', [2.3309953, 0.7948156, 1.5361798])
# ('A_discriminator loss:', 0.036047455)
# ('A_adversarial loss:', 0.36849767)
# ('B_discriminator loss:', 0.13912795)
# ('B_adversarial loss:', 1.0127599)
# ('AC_discriminator loss:', 0.012447068)
# ('BC_discriminator loss:', 0.088568315)
# ('C_adversarial loss:', [2.0878961, 1.3269384, 0.76095772])
# ('A_discriminator loss:', 0.041987222)
# ('A_adversarial loss:', 1.4772309)
# ('B_discriminator loss:', 0.049469661)
# ('B_adversarial loss:', 1.4308594)
# ('AC_discriminator loss:', 0.3701404)
# ('BC_discriminator loss:', 0.16877703)
# ('C_adversarial loss:', [0.62477976, 0.20832984, 0.41644993])
# ('A_discriminator loss:', 0.026833722)
# ('A_adversarial loss:', 1.0177011)
# ('B_discriminator loss:', 0.036593214)
# ('B_adversarial loss:', 0.72346926)
# ('AC_discriminator loss:', 0.018699665)
# ('BC_discriminator loss:', 0.018498378)
# ('C_adversarial loss:', [2.1714685, 1.2360872, 0.93538123])
# ('A_discriminator loss:', 0.043503985)
# ('A_adversarial loss:', 0.43443614)
# ('B_discriminator loss:', 0.082105935)
# ('B_adversarial loss:', 0.70996732)
# ('AC_discriminator loss:', 0.031495381)
# ('BC_discriminator loss:', 0.023091346)
# ('C_adversarial loss:', [2.3211446, 1.1766818, 1.1444627])
# ('A_discriminator loss:', 0.16608229)
# ('A_adversarial loss:', 0.67509305)
# ('B_discriminator loss:', 0.036974747)
# ('B_adversarial loss:', 1.3344097)
# ('AC_discriminator loss:', 0.29440027)
# ('BC_discriminator loss:', 0.59327924)
# ('C_adversarial loss:', [12.083817, 4.1196775, 7.964139])
# ('A_discriminator loss:', 0.03684425)
# ('A_adversarial loss:', 1.7768341)
# ('B_discriminator loss:', 0.054646909)
# ('B_adversarial loss:', 1.0074437)
# ('AC_discriminator loss:', 0.18830231)
# ('BC_discriminator loss:', 0.033913426)
# ('C_adversarial loss:', [1.2290885, 0.46695739, 0.76213121])
# ('A_discriminator loss:', 0.039277572)
# ('A_adversarial loss:', 1.311105)
# ('B_discriminator loss:', 0.0064330241)
# ('B_adversarial loss:', 0.89115399)
# ('AC_discriminator loss:', 0.031982623)
# ('BC_discriminator loss:', 0.045311458)
# ('C_adversarial loss:', [2.3212259, 0.91841125, 1.4028146])
# ('A_discriminator loss:', 0.04306706)
# ('A_adversarial loss:', 1.4291911)
# ('B_discriminator loss:', 0.018291162)
# ('B_adversarial loss:', 1.0179007)
# ('AC_discriminator loss:', 0.10177)
# ('BC_discriminator loss:', 0.033659458)
# ('C_adversarial loss:', [1.120986, 0.36533672, 0.75564927])
# ('A_discriminator loss:', 0.060461532)
# ('A_adversarial loss:', 1.5659258)
# ('B_discriminator loss:', 0.14219441)
# ('B_adversarial loss:', 1.0113014)
# ('AC_discriminator loss:', 0.063064829)
# ('BC_discriminator loss:', 0.10757146)
# ('C_adversarial loss:', [1.0943615, 0.52289116, 0.57147032])
# ('A_discriminator loss:', 0.02345092)
# ('A_adversarial loss:', 0.72343194)
# ('B_discriminator loss:', 0.010216708)
# ('B_adversarial loss:', 1.0366997)
# ('AC_discriminator loss:', 0.035952367)
# ('BC_discriminator loss:', 0.029798865)
# ('C_adversarial loss:', [2.4713123, 1.3013567, 1.1699556])
# ('A_discriminator loss:', 0.034441266)
# ('A_adversarial loss:', 1.0944808)
# ('B_discriminator loss:', 0.26219094)
# ('B_adversarial loss:', 0.10221233)
# ('AC_discriminator loss:', 0.025145506)
# ('BC_discriminator loss:', 0.082395598)
# ('C_adversarial loss:', [2.1808496, 0.91700631, 1.2638432])
# ('A_discriminator loss:', 0.015733689)
# ('A_adversarial loss:', 0.9190439)
# ('B_discriminator loss:', 0.016763221)
# ('B_adversarial loss:', 1.0714254)
# ('AC_discriminator loss:', 0.014777127)
# ('BC_discriminator loss:', 0.017682996)
# ('C_adversarial loss:', [2.4912655, 1.0526991, 1.4385664])
# ('A_discriminator loss:', 0.09273871)
# ('A_adversarial loss:', 0.42011708)
# ('B_discriminator loss:', 0.058083393)
# ('B_adversarial loss:', 1.5669851)
# ('AC_discriminator loss:', 0.028047036)
# ('BC_discriminator loss:', 0.11059825)
# ('C_adversarial loss:', [1.7786257, 1.341361, 0.43726474])
# ('A_discriminator loss:', 0.032631017)
# ('A_adversarial loss:', 0.90029335)
# ('B_discriminator loss:', 0.025576031)
# ('B_adversarial loss:', 1.3319155)
# ('AC_discriminator loss:', 0.015890455)
# ('BC_discriminator loss:', 0.056255084)
# ('C_adversarial loss:', [1.5079215, 1.0383788, 0.46954259])
# ('A_discriminator loss:', 0.077438079)
# ('A_adversarial loss:', 0.75417918)
# ('B_discriminator loss:', 0.012031738)
# ('B_adversarial loss:', 0.98108768)
# ('AC_discriminator loss:', 0.091469392)
# ('BC_discriminator loss:', 0.031483937)
# ('C_adversarial loss:', [1.8915937, 0.88712311, 1.0044706])
# ('A_discriminator loss:', 0.023553455)
# ('A_adversarial loss:', 1.3231081)
# ('B_discriminator loss:', 0.034874845)
# ('B_adversarial loss:', 1.42485)
# ('AC_discriminator loss:', 0.041829936)
# ('BC_discriminator loss:', 0.065014645)
# ('C_adversarial loss:', [1.4540923, 0.79272097, 0.66137123])
# ('A_discriminator loss:', 0.033722252)
# ('A_adversarial loss:', 1.3982751)
# ('B_discriminator loss:', 0.081895486)
# ('B_adversarial loss:', 1.3769292)
# ('AC_discriminator loss:', 0.064798377)
# ('BC_discriminator loss:', 0.17627203)
# ('C_adversarial loss:', [1.02317, 0.61147785, 0.4116922])
# ('A_discriminator loss:', 0.065081738)
# ('A_adversarial loss:', 0.97276938)
# ('B_discriminator loss:', 0.13522318)
# ('B_adversarial loss:', 1.2727187)
# ('AC_discriminator loss:', 0.0655929)
# ('BC_discriminator loss:', 0.18955818)
# ('C_adversarial loss:', [0.93827975, 0.56389433, 0.37438542])
# ('A_discriminator loss:', 0.022257717)
# ('A_adversarial loss:', 0.78015107)
# ('B_discriminator loss:', 0.029423814)
# ('B_adversarial loss:', 1.0966671)
# ('AC_discriminator loss:', 0.024896011)
# ('BC_discriminator loss:', 0.047978055)
# ('C_adversarial loss:', [1.1123228, 0.71533179, 0.39699107])
# ('A_discriminator loss:', 0.034301441)
# ('A_adversarial loss:', 1.3709319)
# ('B_discriminator loss:', 0.22572966)
# ('B_adversarial loss:', 0.57152551)
# ('AC_discriminator loss:', 0.0090806875)
# ('BC_discriminator loss:', 0.039490618)
# ('C_adversarial loss:', [2.2155743, 0.9236697, 1.2919047])
# ('A_discriminator loss:', 0.018462393)
# ('A_adversarial loss:', 0.9101547)
# ('B_discriminator loss:', 0.083367243)
# ('B_adversarial loss:', 0.45996118)
# ('AC_discriminator loss:', 0.019213662)
# ('BC_discriminator loss:', 0.019441077)
# ('C_adversarial loss:', [2.0286274, 0.83316153, 1.1954658])
# ('A_discriminator loss:', 0.033299692)
# ('A_adversarial loss:', 1.143049)
# ('B_discriminator loss:', 0.029825771)
# ('B_adversarial loss:', 0.67747533)
# ('AC_discriminator loss:', 0.027841365)
# ('BC_discriminator loss:', 0.018628675)
# ('C_adversarial loss:', [1.7736018, 0.69585466, 1.0777471])
# ('A_discriminator loss:', 0.015708368)
# ('A_adversarial loss:', 1.1475451)
# ('B_discriminator loss:', 0.018124834)
# ('B_adversarial loss:', 1.0966793)
# ('AC_discriminator loss:', 0.0095068552)
# ('BC_discriminator loss:', 0.022375125)
# ('C_adversarial loss:', [1.802644, 0.98794973, 0.81469423])
# ('A_discriminator loss:', 0.021848893)
# ('A_adversarial loss:', 1.1829336)
# ('B_discriminator loss:', 0.020567726)
# ('B_adversarial loss:', 1.0880749)
# ('AC_discriminator loss:', 0.041956324)
# ('BC_discriminator loss:', 0.025741598)
# ('C_adversarial loss:', [1.2791539, 0.61292839, 0.66622555])
# ('A_discriminator loss:', 0.012794936)
# ('A_adversarial loss:', 1.1866504)
# ('B_discriminator loss:', 0.010355728)
# ('B_adversarial loss:', 1.0662168)
# ('AC_discriminator loss:', 0.024174759)
# ('BC_discriminator loss:', 0.016495125)
# ('C_adversarial loss:', [2.4420857, 1.3144505, 1.1276354])
# ('A_discriminator loss:', 0.010226012)
# ('A_adversarial loss:', 0.84375095)
# ('B_discriminator loss:', 0.05933873)
# ('B_adversarial loss:', 0.67206323)
# ('AC_discriminator loss:', 0.017028)
# ('BC_discriminator loss:', 0.024326494)
# ('C_adversarial loss:', [2.3225579, 1.2790848, 1.043473])
# ('A_discriminator loss:', 0.038994681)
# ('A_adversarial loss:', 1.4356463)
# ('B_discriminator loss:', 0.019865066)
# ('B_adversarial loss:', 1.0799084)
# ('AC_discriminator loss:', 0.0096523426)
# ('BC_discriminator loss:', 0.020832174)
# ('C_adversarial loss:', [2.479388, 1.200011, 1.279377])
# ('A_discriminator loss:', 0.019611459)
# ('A_adversarial loss:', 0.84701872)
# ('B_discriminator loss:', 0.030097663)
# ('B_adversarial loss:', 0.93164998)
# ('AC_discriminator loss:', 0.016690236)
# ('BC_discriminator loss:', 0.019433292)
# ('C_adversarial loss:', [1.3949783, 0.72708404, 0.66789424])
# ('A_discriminator loss:', 0.011786543)
# ('A_adversarial loss:', 1.2369287)
# ('B_discriminator loss:', 0.026808375)
# ('B_adversarial loss:', 0.99807775)
# ('AC_discriminator loss:', 0.010273913)
# ('BC_discriminator loss:', 0.016576823)
# ('C_adversarial loss:', [2.1053798, 1.1636395, 0.94174033])
# ('A_discriminator loss:', 0.037779421)
# ('A_adversarial loss:', 1.1853653)
# ('B_discriminator loss:', 0.052863896)
# ('B_adversarial loss:', 1.1019435)
# ('AC_discriminator loss:', 0.057224058)
# ('BC_discriminator loss:', 0.29745793)
# ('C_adversarial loss:', [30.429819, 0.73575264, 29.694067])
# ('A_discriminator loss:', 0.017505769)
# ('A_adversarial loss:', 1.329805)
# ('B_discriminator loss:', 0.023793796)
# ('B_adversarial loss:', 1.4304521)
# ('AC_discriminator loss:', 0.011962207)
# ('BC_discriminator loss:', 0.030825755)
# ('C_adversarial loss:', [2.0470622, 1.0174153, 1.0296469])
# ('A_discriminator loss:', 0.053533573)
# ('A_adversarial loss:', 0.58376914)
# ('B_discriminator loss:', 0.020570252)
# ('B_adversarial loss:', 0.90998042)
# ('AC_discriminator loss:', 0.069649778)
# ('BC_discriminator loss:', 0.055596322)
# ('C_adversarial loss:', [2.4214087, 1.1351703, 1.2862384])
# ('A_discriminator loss:', 0.018394992)
# ('A_adversarial loss:', 1.0643966)
# ('B_discriminator loss:', 0.015460682)
# ('B_adversarial loss:', 1.198252)
# ('AC_discriminator loss:', 0.013694187)
# ('BC_discriminator loss:', 0.015046075)
# ('C_adversarial loss:', [1.9117551, 1.0818707, 0.82988435])
# ('A_discriminator loss:', 0.021818578)
# ('A_adversarial loss:', 1.1224928)
# ('B_discriminator loss:', 0.02580994)
# ('B_adversarial loss:', 1.217834)
# ('AC_discriminator loss:', 0.045147277)
# ('BC_discriminator loss:', 0.012314566)
# ('C_adversarial loss:', [1.6042459, 0.61290646, 0.9913395])
# ('A_discriminator loss:', 0.085843369)
# ('A_adversarial loss:', 2.3997519)
# ('B_discriminator loss:', 0.086765982)
# ('B_adversarial loss:', 1.1947742)
# ('AC_discriminator loss:', 0.36137083)
# ('BC_discriminator loss:', 0.2177811)
# ('C_adversarial loss:', [0.74893492, 0.44967109, 0.29926383])
# ('A_discriminator loss:', 0.059740007)
# ('A_adversarial loss:', 1.1609697)
# ('B_discriminator loss:', 0.019425707)
# ('B_adversarial loss:', 0.6779415)
# ('AC_discriminator loss:', 0.027891552)
# ('BC_discriminator loss:', 0.0055641639)
# ('C_adversarial loss:', [1.9995399, 0.95501375, 1.0445261])
# ('A_discriminator loss:', 0.0089129256)
# ('A_adversarial loss:', 1.2541993)
# ('B_discriminator loss:', 0.018868942)
# ('B_adversarial loss:', 1.0924927)
# ('AC_discriminator loss:', 0.0157502)
# ('BC_discriminator loss:', 0.072436884)
# ('C_adversarial loss:', [3.0592771, 1.3887055, 1.6705716])
# ('A_discriminator loss:', 0.010153729)
# ('A_adversarial loss:', 0.86616486)
# ('B_discriminator loss:', 0.0064411624)
# ('B_adversarial loss:', 0.95722896)
# ('AC_discriminator loss:', 0.0060741701)
# ('BC_discriminator loss:', 0.0088483514)
# ('C_adversarial loss:', [1.8827759, 1.0592139, 0.82356203])
# ('A_discriminator loss:', 0.00856575)
# ('A_adversarial loss:', 0.90411866)
# ('B_discriminator loss:', 0.23514399)
# ('B_adversarial loss:', 1.032046)
# ('AC_discriminator loss:', 0.01124876)
# ('BC_discriminator loss:', 0.1401871)
# ('C_adversarial loss:', [1.8418932, 1.2021005, 0.63979274])
# ('A_discriminator loss:', 0.019478723)
# ('A_adversarial loss:', 1.0728633)
# ('B_discriminator loss:', 0.030892152)
# ('B_adversarial loss:', 1.3496777)
# ('AC_discriminator loss:', 0.018434156)
# ('BC_discriminator loss:', 0.04243964)
# ('C_adversarial loss:', [1.6440339, 0.805309, 0.83872497])
# ('A_discriminator loss:', 0.019944116)
# ('A_adversarial loss:', 0.92877495)
# ('B_discriminator loss:', 0.024203269)
# ('B_adversarial loss:', 1.2711716)
# ('AC_discriminator loss:', 0.027053114)
# ('BC_discriminator loss:', 0.025046587)
# ('C_adversarial loss:', [1.8233248, 0.62258136, 1.2007434])
# ('A_discriminator loss:', 0.038221728)
# ('A_adversarial loss:', 1.4795678)
# ('B_discriminator loss:', 0.035880849)
# ('B_adversarial loss:', 1.4523866)
# ('AC_discriminator loss:', 0.10625844)
# ('BC_discriminator loss:', 0.1377594)
# ('C_adversarial loss:', [1.2149268, 1.1319323, 0.08299458])
# ('A_discriminator loss:', 0.12143183)
# ('A_adversarial loss:', 6.7499962)
# ('B_discriminator loss:', 0.012359491)
# ('B_adversarial loss:', 1.0145729)
# ('AC_discriminator loss:', 0.019798785)
# ('BC_discriminator loss:', 0.0091675539)
# ('C_adversarial loss:', [2.0457449, 1.0330284, 1.0127165])
# ('A_discriminator loss:', 0.014839955)
# ('A_adversarial loss:', 0.9221611)
# ('B_discriminator loss:', 0.020177335)
# ('B_adversarial loss:', 0.95120943)
# ('AC_discriminator loss:', 0.0073177023)
# ('BC_discriminator loss:', 0.012000651)
# ('C_adversarial loss:', [1.8944945, 0.91071498, 0.98377955])
# ('A_discriminator loss:', 0.012754294)
# ('A_adversarial loss:', 1.1827266)
# ('B_discriminator loss:', 0.017192591)
# ('B_adversarial loss:', 1.1084534)
# ('AC_discriminator loss:', 0.016449345)
# ('BC_discriminator loss:', 0.011306012)
# ('C_adversarial loss:', [1.7845806, 0.74140465, 1.0431759])
# ('A_discriminator loss:', 0.047137838)
# ('A_adversarial loss:', 1.4193718)
# ('B_discriminator loss:', 0.018379169)
# ('B_adversarial loss:', 0.91626227)
# ('AC_discriminator loss:', 0.35118741)
# ('BC_discriminator loss:', 0.018713683)
# ('C_adversarial loss:', [1.8788395, 0.74866122, 1.1301782])
# ('A_discriminator loss:', 0.027667234)
# ('A_adversarial loss:', 1.117906)
# ('B_discriminator loss:', 0.069896981)
# ('B_adversarial loss:', 0.40800563)
# ('AC_discriminator loss:', 0.015026817)
# ('BC_discriminator loss:', 0.1030004)
# ('C_adversarial loss:', [2.4160082, 0.87247086, 1.5435374])
# ('A_discriminator loss:', 0.010392136)
# ('A_adversarial loss:', 1.0430821)
# ('B_discriminator loss:', 0.07743559)
# ('B_adversarial loss:', 0.74204111)
# ('AC_discriminator loss:', 0.010728052)
# ('BC_discriminator loss:', 0.079855539)
# ('C_adversarial loss:', [1.8528931, 0.99061662, 0.86227643])
# ('A_discriminator loss:', 0.032176066)
# ('A_adversarial loss:', 1.1900692)
# ('B_discriminator loss:', 0.011921302)
# ('B_adversarial loss:', 1.1659206)
# ('AC_discriminator loss:', 0.043800104)
# ('BC_discriminator loss:', 0.009989664)
# ('C_adversarial loss:', [2.025425, 1.1341375, 0.89128751])
# ('A_discriminator loss:', 0.060059391)
# ('A_adversarial loss:', 1.3592329)
# ('B_discriminator loss:', 0.051700018)
# ('B_adversarial loss:', 1.0405183)
# ('AC_discriminator loss:', 0.035469759)
# ('BC_discriminator loss:', 0.18138108)
# ('C_adversarial loss:', [1.6791519, 1.4449352, 0.23421673])
# ('A_discriminator loss:', 0.010881299)
# ('A_adversarial loss:', 1.2294134)
# ('B_discriminator loss:', 0.50495994)
# ('B_adversarial loss:', 2.0756533)
# ('AC_discriminator loss:', 0.019802054)
# ('BC_discriminator loss:', 0.024572169)
# ('C_adversarial loss:', [1.3462964, 0.56472456, 0.78157187])
# ('A_discriminator loss:', 0.012782049)
# ('A_adversarial loss:', 1.1719509)
# ('B_discriminator loss:', 0.0077667339)
# ('B_adversarial loss:', 1.1356971)
# ('AC_discriminator loss:', 0.01170689)
# ('BC_discriminator loss:', 0.01083203)
# ('C_adversarial loss:', [2.177696, 0.92831433, 1.2493817])
# ('A_discriminator loss:', 0.011133477)
# ('A_adversarial loss:', 0.8893131)
# ('B_discriminator loss:', 0.090565816)
# ('B_adversarial loss:', 0.92998219)
# ('AC_discriminator loss:', 0.013398314)
# ('BC_discriminator loss:', 0.065951161)
# ('C_adversarial loss:', [2.1009974, 1.0169685, 1.084029])
# ('A_discriminator loss:', 0.0230699)
# ('A_adversarial loss:', 1.0640527)
# ('B_discriminator loss:', 0.025809562)
# ('B_adversarial loss:', 1.4023167)
# ('AC_discriminator loss:', 0.0094298003)
# ('BC_discriminator loss:', 0.015996154)
# ('C_adversarial loss:', [2.0290031, 1.1048161, 0.924187])
# ('A_discriminator loss:', 0.11419757)
# ('A_adversarial loss:', 0.86074674)
# ('B_discriminator loss:', 0.70922023)
# ('B_adversarial loss:', 0.67538142)
# ('AC_discriminator loss:', 0.10145466)
# ('BC_discriminator loss:', 0.10338528)
# ('C_adversarial loss:', [1.8234155, 0.93221378, 0.89120179])
