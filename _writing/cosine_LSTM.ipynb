# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
# Out:
# Using Theano backend.

# %%
import matplotlib.pyplot as plt

import theano

# %matplotlib inline

# %%
dataset = np.cos(np.arange(1000)*(20*np.pi/1000))[:,None]
plot_x = np.arange(1000)
plot_y = dataset
plt.plot(plot_x, plot_y)
plt.show()

# %% [markdown]
# # LSTMs

# %%
# dataset = np.cos(np.arange(1000)*(20*np.pi/1000))[:,None]
# plt_plot(y = dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9d1de205ac86> in <module>()
#       1 dataset = np.cos(np.arange(1000)*(20*np.pi/1000))[:,None]
# ----> 2 plt_plot(y = dataset)
#
# NameError: name 'plt_plot' is not defined

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ## Window of 20 time steps

# %%
look_back = 20
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
train.shape
# Out:
# (670, 1)

# %%
trainX.shape
# Out:
# (650, 20, 1)

# %%
trainY.shape
# Out:
# (650,)

# %%
# %%time
theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(32,input_dim=1))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, nb_epoch=100, batch_size=batch_size, verbose=2)
# Out:
# Epoch 1/100
# 1s - loss: 0.0194
# Epoch 2/100
# 1s - loss: 0.0070
# Epoch 3/100
# 1s - loss: 0.0060
# Epoch 4/100
# 1s - loss: 0.0046
# Epoch 5/100
# 1s - loss: 0.0043
# Epoch 6/100
# 1s - loss: 0.0037
# Epoch 7/100
# 1s - loss: 0.0036
# Epoch 8/100
# 1s - loss: 0.0027
# Epoch 9/100
# 1s - loss: 0.0030
# Epoch 10/100
# 1s - loss: 0.0031
# Epoch 11/100
# 1s - loss: 0.0030
# Epoch 12/100
# 1s - loss: 0.0026
# Epoch 13/100
# 1s - loss: 0.0022
# Epoch 14/100
# 1s - loss: 0.0026
# Epoch 15/100
# 1s - loss: 0.0023
# Epoch 16/100
# 1s - loss: 0.0023
# Epoch 17/100
# 1s - loss: 0.0020
# Epoch 18/100
# 1s - loss: 0.0022
# Epoch 19/100
# 1s - loss: 0.0026
# Epoch 20/100
# 1s - loss: 0.0022
# Epoch 21/100
# 1s - loss: 0.0025
# Epoch 22/100
# 1s - loss: 0.0023
# Epoch 23/100
# 1s - loss: 0.0023
# Epoch 24/100
# 1s - loss: 0.0021
# Epoch 25/100
# 1s - loss: 0.0021
# Epoch 26/100
# 1s - loss: 0.0023
# Epoch 27/100
# 1s - loss: 0.0020
# Epoch 28/100
# 1s - loss: 0.0021
# Epoch 29/100
# 1s - loss: 0.0024
# Epoch 30/100
# 1s - loss: 0.0021
# Epoch 31/100
# 1s - loss: 0.0023
# Epoch 32/100
# 1s - loss: 0.0022
# Epoch 33/100
# 1s - loss: 0.0021
# Epoch 34/100
# 1s - loss: 0.0019
# Epoch 35/100
# 1s - loss: 0.0021
# Epoch 36/100
# 1s - loss: 0.0021
# Epoch 37/100
# 1s - loss: 0.0023
# Epoch 38/100
# 1s - loss: 0.0021
# Epoch 39/100
# 1s - loss: 0.0022
# Epoch 40/100
# 1s - loss: 0.0020
# Epoch 41/100
# 1s - loss: 0.0020
# Epoch 42/100
# 1s - loss: 0.0019
# Epoch 43/100
# 1s - loss: 0.0021
# Epoch 44/100
# 1s - loss: 0.0020
# Epoch 45/100
# 1s - loss: 0.0022
# Epoch 46/100
# 1s - loss: 0.0022
# Epoch 47/100
# 1s - loss: 0.0022
# Epoch 48/100
# 1s - loss: 0.0019
# Epoch 49/100
# 1s - loss: 0.0019
# Epoch 50/100
# 1s - loss: 0.0022
# Epoch 51/100
# 1s - loss: 0.0022
# Epoch 52/100
# 1s - loss: 0.0020
# Epoch 53/100
# 1s - loss: 0.0020
# Epoch 54/100
# 1s - loss: 0.0018
# Epoch 55/100
# 1s - loss: 0.0021
# Epoch 56/100
# 1s - loss: 0.0020
# Epoch 57/100
# 1s - loss: 0.0022
# Epoch 58/100
# 1s - loss: 0.0021
# Epoch 59/100
# 1s - loss: 0.0020
# Epoch 60/100
# 1s - loss: 0.0021
# Epoch 61/100
# 1s - loss: 0.0020
# Epoch 62/100
# 1s - loss: 0.0022
# Epoch 63/100
# 1s - loss: 0.0020
# Epoch 64/100
# 1s - loss: 0.0019
# Epoch 65/100
# 1s - loss: 0.0019
# Epoch 66/100
# 1s - loss: 0.0022
# Epoch 67/100
# 1s - loss: 0.0020
# Epoch 68/100
# 1s - loss: 0.0022
# Epoch 69/100
# 1s - loss: 0.0022
# Epoch 70/100
# 1s - loss: 0.0022
# Epoch 71/100
# 1s - loss: 0.0018
# Epoch 72/100
# 1s - loss: 0.0023
# Epoch 73/100
# 1s - loss: 0.0021
# Epoch 74/100
# 1s - loss: 0.0020
# Epoch 75/100
# 1s - loss: 0.0020
# Epoch 76/100
# 1s - loss: 0.0021
# Epoch 77/100
# 1s - loss: 0.0020
# Epoch 78/100
# 1s - loss: 0.0020
# Epoch 79/100
# 1s - loss: 0.0019
# Epoch 80/100
# 1s - loss: 0.0018
# Epoch 81/100
# 1s - loss: 0.0017
# Epoch 82/100
# 1s - loss: 0.0020
# Epoch 83/100
# 1s - loss: 0.0019
# Epoch 84/100
# 1s - loss: 0.0021
# Epoch 85/100
# 1s - loss: 0.0020
# Epoch 86/100
# 1s - loss: 0.0022
# Epoch 87/100
# 1s - loss: 0.0021
# Epoch 88/100
# 1s - loss: 0.0019
# Epoch 89/100
# 1s - loss: 0.0022
# Epoch 90/100
# 1s - loss: 0.0020
# Epoch 91/100
# 1s - loss: 0.0020
# Epoch 92/100
# 1s - loss: 0.0020
# Epoch 93/100
# 1s - loss: 0.0020
# Epoch 94/100
# 1s - loss: 0.0022
# Epoch 95/100
# 1s - loss: 0.0020
# Epoch 96/100
# 1s - loss: 0.0022
# Epoch 97/100
# 1s - loss: 0.0021
# Epoch 98/100
# 1s - loss: 0.0018
# Epoch 99/100
# 1s - loss: 0.0018
# Epoch 100/100
# 1s - loss: 0.0021
# CPU times: user 2min 55s, sys: 354 ms, total: 2min 56s
# Wall time: 2min 56s
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(32, input_shape=(None, 1))`

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# ('Train Score: ', 0.00028182997409134788)
# ('Test Score: ', 0.000329150588859413)

# %%
look_ahead = 250
trainPredict = [np.vstack([trainX[-1][1:], trainY[-1]])]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([trainPredict[-1]]), batch_size=batch_size)
    predictions[i] = prediction
    trainPredict.append(np.vstack([trainPredict[-1][1:],prediction]))

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()

# %% [markdown]
# ## Stateful LSTMs

# %%
look_back = 20
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# %%time
theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
# model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
# model.add(Dropout(0.3))
# model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
# model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(200):
    model.fit(trainX, trainY, nb_epoch=1, batch_size=batch_size, verbose=0, shuffle=False)
    model.reset_states()
# Out:
# CPU times: user 5min 21s, sys: 563 ms, total: 5min 21s
# Wall time: 5min 23s

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# ('Train Score: ', 0.0001615088190010283)
# ('Test Score: ', 0.00017891165000383764)

# %%
look_ahead = 250
trainPredict = [np.vstack([trainX[-1][1:], trainY[-1]])]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([trainPredict[-1]]), batch_size=batch_size)
    predictions[i] = prediction
    trainPredict.append(np.vstack([trainPredict[-1][1:],prediction]))

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()

# %% [markdown]
# ## Stateful LSTMs with wider window

# %%
look_back = 40
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# %%time
theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
# model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
# model.add(Dropout(0.3))
# model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
# model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(200):
    model.fit(trainX, trainY, nb_epoch=1, batch_size=batch_size, verbose=0, shuffle=False)
    model.reset_states()
# Out:
# CPU times: user 8min 20s, sys: 554 ms, total: 8min 20s
# Wall time: 8min 20s

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# ('Train Score: ', 0.00026558322096974506)
# ('Test Score: ', 0.00024913668091124173)

# %%
look_ahead = 250
trainPredict = [np.vstack([trainX[-1][1:], trainY[-1]])]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([trainPredict[-1]]), batch_size=batch_size)
    predictions[i] = prediction
    trainPredict.append(np.vstack([trainPredict[-1][1:],prediction]))

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()

# %% [markdown]
# ## Stateful LSTMs, Stacked

# %%
# %%time
theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(200):
    model.fit(trainX, trainY, nb_epoch=1, batch_size=batch_size, verbose=0, shuffle=False)
    model.reset_states()
# Out:
# CPU times: user 16min 32s, sys: 1.19 s, total: 16min 33s
# Wall time: 16min 35s

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# ('Train Score: ', 0.00097373255332285687)
# ('Test Score: ', 0.00097995249774526219)

# %%
look_ahead = 250
trainPredict = [np.vstack([trainX[-1][1:], trainY[-1]])]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([trainPredict[-1]]), batch_size=batch_size)
    predictions[i] = prediction
    trainPredict.append(np.vstack([trainPredict[-1][1:],prediction]))

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()

# %% [markdown]
# ## Stateful LSTM stacked DEEPER!

# %%
# %%time
theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
for i in range(2):
    model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
    model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(200):
    model.fit(trainX, trainY, nb_epoch=1, batch_size=batch_size, verbose=0, shuffle=False)
    model.reset_states()
# Out:
# CPU times: user 24min 59s, sys: 2.25 s, total: 25min 2s
# Wall time: 25min 10s

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# ('Train Score: ', 0.00038190693159080499)
# ('Test Score: ', 0.00041797057589041504)

# %%
look_ahead = 250
trainPredict = [np.vstack([trainX[-1][1:], trainY[-1]])]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([trainPredict[-1]]), batch_size=batch_size)
    predictions[i] = prediction
    trainPredict.append(np.vstack([trainPredict[-1][1:],prediction]))

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()

# %% [markdown]
# ## Normal Deep Learning in Keras

# %%
# %%time
trainX = np.squeeze(trainX)
testX = np.squeeze(testX)
theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(Dense(output_dim=32,input_dim=40,activation="relu"))
model.add(Dropout(0.3))
for i in range(2):
    model.add(Dense(output_dim=32,activation="relu"))
    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adagrad')
model.fit(trainX, trainY, nb_epoch=100, batch_size=32, verbose=0)
# Out:
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/ipykernel/__main__.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=32, activation="relu", input_dim=40)`
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=32, activation="relu")`
# CPU times: user 3.02 s, sys: 113 ms, total: 3.14 s
# Wall time: 7.85 s

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# ('Train Score: ', 0.010848890123941732)
# ('Test Score: ', 0.010028708001092271)

# %%
look_ahead = 250
xval = np.hstack([trainX[-1][1:], trainY[-1]])[None,:]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(xval, batch_size=32)
    predictions[i] = prediction
    xval = np.hstack([xval[:,1:],prediction])

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()
