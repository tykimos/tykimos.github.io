# %%
import os
import pandas

dir_path = './Data_RNN'

df = pandas.DataFrame()
    
for file_name in os.listdir(dir_path):
    file_path = os.path.join(dir_path, file_name)
    if not os.path.isdir(file_path):
        ext = os.path.splitext(file_path)[-1]
        if ext == '.txt': 
            print(file_path)
            
            curr_df = pandas.read_csv(file_path, delim_whitespace=True, header=None, usecols=[6])
            df = df.append(curr_df)
# Out:
# ./Data_RNN/201301.txt
# ./Data_RNN/201302.txt
# ./Data_RNN/201306.txt
# ./Data_RNN/201307.txt
# ./Data_RNN/201401.txt
# ./Data_RNN/201402.txt
# ./Data_RNN/201403.txt
# ./Data_RNN/201405.txt
# ./Data_RNN/201406.txt
# ./Data_RNN/201503.txt
# ./Data_RNN/201601.txt

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

dataset = df.values
dataset = dataset.astype('float32')
dataset = np.log10(dataset)

# normalize
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)
dataset = np.reshape(dataset, (11, 288, 1))

#dataset.shape

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

for ds in dataset:
    plt.plot(ds)
    
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

model = Sequential()
model.add(LSTM(32, batch_input_shape=(1, 20, 1), stateful=True, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(1, 20, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))

#model = Sequential()
#model.add(LSTM(100, batch_input_shape=(1, 20, 1), stateful=True))
#model.add(Dropout(0.3))
#model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Using Theano backend.

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        dataX.append(dataset[i:( i + look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
for epoch in range(10):
    
    for event_idx in range(10):
    
        print('epoch : ' + str(epoch) + ' | event id : ' + str(event_idx))
        
        trainX, trainY = create_dataset(dataset[event_idx], 20)
        trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1)) # samples, time steps, features

        model.fit(trainX, trainY, nb_epoch=1, batch_size=1, verbose=2, shuffle=False)
        model.reset_states()
# Out:
# epoch : 0 | event id : 0
# Epoch 1/1
# 1s - loss: 0.0199
# epoch : 0 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0188
# epoch : 0 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0142
# epoch : 0 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0056
# epoch : 0 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0080
# epoch : 0 | event id : 5
# Epoch 1/1
# 1s - loss: 0.0068
# epoch : 0 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0030
# epoch : 0 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0120
# epoch : 0 | event id : 8
# Epoch 1/1
# 1s - loss: 0.0051
# epoch : 0 | event id : 9
# Epoch 1/1
# 1s - loss: 0.0031
# epoch : 1 | event id : 0
# Epoch 1/1
# 1s - loss: 0.0026
# epoch : 1 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0083
# epoch : 1 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0058
# epoch : 1 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0018
# epoch : 1 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0062
# epoch : 1 | event id : 5
# Epoch 1/1
# 1s - loss: 0.0025
# epoch : 1 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0044
# epoch : 1 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0114
# epoch : 1 | event id : 8
# Epoch 1/1
# 1s - loss: 0.0016
# epoch : 1 | event id : 9
# Epoch 1/1
# 1s - loss: 0.0013
# epoch : 2 | event id : 0
# Epoch 1/1
# 1s - loss: 7.4831e-04
# epoch : 2 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0074
# epoch : 2 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0032
# epoch : 2 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0021
# epoch : 2 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0055
# epoch : 2 | event id : 5
# Epoch 1/1
# 1s - loss: 0.0011
# epoch : 2 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0057
# epoch : 2 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0105
# epoch : 2 | event id : 8
# Epoch 1/1
# 1s - loss: 0.0012
# epoch : 2 | event id : 9
# Epoch 1/1
# 1s - loss: 9.9607e-04
# epoch : 3 | event id : 0
# Epoch 1/1
# 1s - loss: 7.9128e-04
# epoch : 3 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0088
# epoch : 3 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0024
# epoch : 3 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0019
# epoch : 3 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0049
# epoch : 3 | event id : 5
# Epoch 1/1
# 1s - loss: 6.3525e-04
# epoch : 3 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0066
# epoch : 3 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0113
# epoch : 3 | event id : 8
# Epoch 1/1
# 1s - loss: 6.7106e-04
# epoch : 3 | event id : 9
# Epoch 1/1
# 1s - loss: 6.4492e-04
# epoch : 4 | event id : 0
# Epoch 1/1
# 1s - loss: 9.7178e-04
# epoch : 4 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0121
# epoch : 4 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0021
# epoch : 4 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0024
# epoch : 4 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0052
# epoch : 4 | event id : 5
# Epoch 1/1
# 1s - loss: 5.5905e-04
# epoch : 4 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0083
# epoch : 4 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0109
# epoch : 4 | event id : 8
# Epoch 1/1
# 1s - loss: 4.7092e-04
# epoch : 4 | event id : 9
# Epoch 1/1
# 1s - loss: 6.5794e-04
# epoch : 5 | event id : 0
# Epoch 1/1
# 1s - loss: 0.0011
# epoch : 5 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0136
# epoch : 5 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0020
# epoch : 5 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0029
# epoch : 5 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0064
# epoch : 5 | event id : 5
# Epoch 1/1
# 1s - loss: 5.8481e-04
# epoch : 5 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0091
# epoch : 5 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0117
# epoch : 5 | event id : 8
# Epoch 1/1
# 1s - loss: 5.0164e-04
# epoch : 5 | event id : 9
# Epoch 1/1
# 1s - loss: 6.0969e-04
# epoch : 6 | event id : 0
# Epoch 1/1
# 1s - loss: 9.1391e-04
# epoch : 6 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0125
# epoch : 6 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0023
# epoch : 6 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0042
# epoch : 6 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0070
# epoch : 6 | event id : 5
# Epoch 1/1
# 1s - loss: 6.2975e-04
# epoch : 6 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0112
# epoch : 6 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0175
# epoch : 6 | event id : 8
# Epoch 1/1
# 1s - loss: 4.0289e-04
# epoch : 6 | event id : 9
# Epoch 1/1
# 1s - loss: 6.2538e-04
# epoch : 7 | event id : 0
# Epoch 1/1
# 1s - loss: 0.0013
# epoch : 7 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0158
# epoch : 7 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0024
# epoch : 7 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0032
# epoch : 7 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0042
# epoch : 7 | event id : 5
# Epoch 1/1
# 1s - loss: 6.4200e-04
# epoch : 7 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0095
# epoch : 7 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0136
# epoch : 7 | event id : 8
# Epoch 1/1
# 1s - loss: 3.8962e-04
# epoch : 7 | event id : 9
# Epoch 1/1
# 1s - loss: 6.1820e-04
# epoch : 8 | event id : 0
# Epoch 1/1
# 1s - loss: 0.0012
# epoch : 8 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0157
# epoch : 8 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0025
# epoch : 8 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0040
# epoch : 8 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0051
# epoch : 8 | event id : 5
# Epoch 1/1
# 1s - loss: 6.5107e-04
# epoch : 8 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0089
# epoch : 8 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0122
# epoch : 8 | event id : 8
# Epoch 1/1
# 1s - loss: 3.6283e-04
# epoch : 8 | event id : 9
# Epoch 1/1
# 1s - loss: 6.0998e-04
# epoch : 9 | event id : 0
# Epoch 1/1
# 1s - loss: 0.0011
# epoch : 9 | event id : 1
# Epoch 1/1
# 1s - loss: 0.0141
# epoch : 9 | event id : 2
# Epoch 1/1
# 1s - loss: 0.0025
# epoch : 9 | event id : 3
# Epoch 1/1
# 1s - loss: 0.0043
# epoch : 9 | event id : 4
# Epoch 1/1
# 1s - loss: 0.0045
# epoch : 9 | event id : 5
# Epoch 1/1
# 1s - loss: 5.8132e-04
# epoch : 9 | event id : 6
# Epoch 1/1
# 1s - loss: 0.0080
# epoch : 9 | event id : 7
# Epoch 1/1
# 1s - loss: 0.0110
# epoch : 9 | event id : 8
# Epoch 1/1
# 1s - loss: 4.1389e-04
# epoch : 9 | event id : 9
# Epoch 1/1
# 1s - loss: 6.0390e-04
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/keras/models.py:837: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '

# %%
testX, testY = create_dataset(dataset[10], 20)
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

testPredict = [testX[0]]

# %%
look_ahead = 288 - 20
predictions = np.zeros((look_ahead, 1))
    
for i in range(look_ahead):
    prediction = model.predict(np.array([testPredict[-1]]), batch_size=1, verbose=0)
    predictions[i] = prediction
    testPredict.append(np.vstack([testPredict[-1][1:], prediction]))
    
model.reset_states()

# %%
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead), predictions,'r', label="prediction")
plt.plot(np.arange(look_ahead), testY, label="test function")
plt.legend()
plt.show()

# %%
testX, testY = create_dataset(dataset[10], 20)
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

testPredict = [testX[0]]

look_real = 100
look_ahead = 287-100

predictions = np.zeros((look_real + look_ahead, 1))

for i in range(look_real):
    
    prediction = model.predict(np.array([testPredict[-1]]), batch_size=1, verbose=0)
    predictions[i] = prediction
    testPredict.append(np.vstack([testPredict[-1][1:], testY[i]]))
    
for i in range(look_ahead):
    prediction = model.predict(np.array([testPredict[-1]]), batch_size=1, verbose=0)
    predictions[look_real + i] = prediction
    testPredict.append(np.vstack([testPredict[-1][1:], prediction]))
    
model.reset_states()

# %%
plt.figure(figsize=(12,5))
plt.plot(np.arange(287), predictions,'r', label="prediction")
plt.plot(np.arange(287), testY, label="test function")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7be06df4c4b6> in <module>()
#       1 plt.figure(figsize=(12,5))
#       2 plt.plot(np.arange(287), predictions,'r', label="prediction")
# ----> 3 plt.plot(np.arange(287), testY, label="test function")
#       4 plt.legend()
#       5 plt.show()
#
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# /Users/tykimos/Projects/Keras/venv/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (287,) and (268,)
